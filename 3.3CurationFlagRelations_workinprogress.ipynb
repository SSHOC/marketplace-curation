# %% [markdown]
# # Notebook 3.3 - Curation-flag-relation
#
# This notebook analyses the relations between items of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-relation` and `curation-detail` properties.
#
# This notebook flags Marketplace items for which contextualisation quality is low (based on interlinked items), helping Moderators improve the relations between items.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 3 sections:
#
# 0. Requirements to run the notebook
# 1. Check the number of relations per item
# 2. Flag items with not enough relations

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel
utils=hel.Util()

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  28230  tool-or-service                                             140kit
# 1  36324  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  36552  tool-or-service                                              3DHOP
# 3  36555  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  36189  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       SIU1nO  2021-11-23T17:24:25+0000  approved
# 1       4gDAHv  2022-01-13T11:49:02+0000  approved
# 2       UcxOmD  2022-01-13T11:50:31+0000  approved
# 3       uFIMPQ  2022-01-13T11:50:32+0000  approved
# 4       kAkzuz  2022-01-13T11:47:44+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1  3DF Zephyr\[1\]\[2\] is a commercial photogram...
# 2  3DHOP (3D Heritage Online Presenter) is an ope...
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 2224, 'name': 'Ian Pearce, D...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'mode-of-use', 'label': 'Mo...          []  ...
# 1  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 2  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 3                                                 []          []  ...
# 4  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
#
#   thumbnail.info.mediaId thumbnail.info.category thumbnail.info.filename  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#   thumbnail.info.mimeType  thumbnail.info.hasThumbnail  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#   thumbnail.info.location.sourceUrl thumbnail.caption dateCreated  \
# 0                               NaN               NaN         NaN
# 1                               NaN               NaN         NaN
# 2                               NaN               NaN         NaN
# 3                               NaN               NaN         NaN
# 4                               NaN               NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 37 columns]

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'description', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 303  12634       l8gLBb  dataset
# 304  12631       xvYQQ4  dataset
# 305  12632       IdZGtV  dataset
# 306  12633       OMny6U  dataset
# 307  12589       YnEaU0  dataset
#
#                                                  label  \
# 303                    Yelp Academic Challenge Dataset
# 304                                            YelpCHI
# 305                                            YelpNYC
# 306                                            YelpZIP
# 307  "You Are Where You Tweet: A Content-Based Appr...
#
#                                            description  \
# 303  The Yelp dataset is a subset of our businesses...
# 304  This dataset is collected from Yelp.com and fi...
# 305  This dataset is collected from Yelp.com and fi...
# 306  This dataset is collected from Yelp.com and fi...
# 307  This dataset is a collection of scraped public...
#
#                                           contributors  \
# 303  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 304  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 303                    [https://www.yelp.com/dataset]  Humanities Data
# 304  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 305  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 307   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check the number of relations per item
#
# By default, and according to rules set up in the Editorial Guidelines, items in the SSH Open Marketplace should be interlinked.

# %%
df_rel_it=utils.getAllRelatedItems()
df_rel_it.sort_values('label').head()
# Out:
#     item_persistentId    item_category            item_label   relation.label  \
# 155            jW7Juy  tool-or-service  MicMac documentation  Is mentioned in
# 156            jW7Juy  tool-or-service  MicMac documentation  Is mentioned in
# 293            gNfOzz  tool-or-service               YouTube  Is mentioned in
# 238            h2MFPS  tool-or-service       TEI Boilerplate       Relates to
# 134            gHCDwq  tool-or-service                Kindle  Is mentioned in
#
#     persistentId     category  \
# 155       GwNSio         step
# 156       7iPdD9         step
# 293       rSRIZx  publication
# 238       UK7Sij  publication
# 134       q0d7jU  publication
#
#                                                  label workflowId  \
# 155                                      Preservation      0BLi83
# 156                                     Visualisation      0BLi83
# 293  "My Name is Lizzie Bennet - " Reading, Partici...        NaN
# 238  "On the record" - transcribing and valorizing ...        NaN
# 134             A Scholarly Edition for Mobile Devices        NaN
#
#                                            description    relation.code
# 155  To convert and represent the information in a ...  is-mentioned-in
# 156  Decide what the final user will be able to see...  is-mentioned-in
# 293                            No description provided  is-mentioned-in
# 238  Qualitative interviews constitute an important...       relates-to
# 134                            No description provided  is-mentioned-in

# %%
df_rel_it.shape
# Out:
# (607, 10)

# %% [markdown]
# The following cell code returns a dataframe with all the publications having 3 related items, it uses the function __getRelateditems (itemcategories, operator, nrelitems)__  returns a dataframe with items in a specific category having related items.
# The parameters are:
#
# <ul>
#     <li>categories: the list of categories. This parameter is mandatory, if the search should be done in all categories the keyword *all* can be used</li>
#     <li> the operator.  Optional, accepted values are =, &lt; and &gt; (the default) </li>
#     <li> nrelitems: an optional parameter, if not present all items are returned.</li>
# </ul>

# %%
df_test_ri=utils.getRelatedItems('all', '<', 3)
df_test_ri.head(7)
# Out:
#                       MPUrl persistentId           category  \
# 0        publication/rSRIZx       rSRIZx        publication
# 1        publication/UK7Sij       UK7Sij        publication
# 2  training-material/baDTwh       baDTwh  training-material
# 3    tool-or-service/4gDAHv       4gDAHv    tool-or-service
# 4    tool-or-service/UcxOmD       UcxOmD    tool-or-service
# 5  training-material/T3JbA2       T3JbA2  training-material
# 6    tool-or-service/uFIMPQ       uFIMPQ    tool-or-service
#
#                                                label   relation.label  \
# 0  "My Name is Lizzie Bennet - " Reading, Partici...         Mentions
# 1  "On the record" - transcribing and valorizing ...    Is related to
# 2  2.1 Error rates and ground truth - Text Digiti...  Is mentioned in
# 3  3DF Zephyr - photogrammetry software - 3d mode...  Is mentioned in
# 4                                              3DHOP  Is mentioned in
# 5                                     3DHOP - How To  Is mentioned in
# 6                3DHOP: 3D Heritage Online Presenter  Is mentioned in
#
#   relitem_persistentId relItem_category  \
# 0               gNfOzz  tool-or-service
# 1               h2MFPS  tool-or-service
# 2               KEugTm             step
# 3               Vb1dhh             step
# 4               mSWgiF             step
# 5               mSWgiF             step
# 6               mSWgiF             step
#
#                                        relItem_label  \
# 0                                            YouTube
# 1                                    TEI Boilerplate
# 2                Test on a subset and assess quality
# 3  Georeferencing the surveyed data: Using a GNSS...
# 4                                      Visualisation
# 5                                      Visualisation
# 6                                      Visualisation
#
#                                  relItem_description    relation.code  value  \
# 0           http://www.wikidata.org/entity/Q16971117         mentions      1
# 1  TEI Boilerplate is a lightweight solution for ...    is-related-to      1
# 2  The first step to take is the definition of a ...  is-mentioned-in      1
# 3  Using well materialized Ground Control Points ...  is-mentioned-in      1
# 4  Visualize 3D models requires specific (web-bas...  is-mentioned-in      1
# 5  Visualize 3D models requires specific (web-bas...  is-mentioned-in      1
# 6  Visualize 3D models requires specific (web-bas...  is-mentioned-in      1
#
#   workflowId
# 0        NaN
# 1        NaN
# 2     qYzKVU
# 3     wqeZGu
# 4     B3V0jJ
# 5     B3V0jJ
# 6     B3V0jJ

# %%
df_test_ri.shape
# Out:
# (423, 12)

# %% [markdown]
# ## 2. Flag items with with not enough relations

# %%
curation_flag_property={"code": "curation-flag-relations"}
curation_detail_property={"code": "curation-detail"}
