# %% [markdown]
# # Notebook 5.1 - Curation-Keywords (alpha release)
#
# The final release of this notebook will implement the workflow defined in:
#
# [Curating keywords](https://gitlab.gwdg.de/sshoc/marketplace-curation/-/issues/1#note_71056) GitLab issue
#
# The notebook is composed of 4 sections:
#
# 0. Import external libraries and loads the MP dataset and the google sheet
# 1. Look for vocabulary terms with the value from the column *Keyword to map*
# 2. Look for the term in the column *Map to*
# 3. Go through all MP items to look for the *keywords-to-map* in the keyword-dynamic-property

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel

# %% [markdown]
# ### 0.2 Get the data

# %% [markdown]
# Get the MarketPlace dataset

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# Get the list of keywords from the [gsheet](https://docs.google.com/spreadsheets/d/1-Oh9_SxIhfMAT6KNJrMf4LetCpy5s1fHZEyTL__TUVA/edit#gid=0)

# %%
sheet_id = '1-Oh9_SxIhfMAT6KNJrMf4LetCpy5s1fHZEyTL__TUVA'
sheet_name = 'Mappings'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
df_keywords=pd.read_csv(url)

# %% [markdown]
# ### 0.3 A look at the data

# %% [markdown]
# A few lines of the gsheet

# %%
df_keywords.head()
# Out:
#   Keyword to map                                             Map to  \
# 0    Linguistics  https://vocabs.acdh.oeaw.ac.at/oefosdiscipline...
# 1        History  https://vocabs.acdh.oeaw.ac.at/oefosdiscipline...
# 2     Literature  https://vocabs.acdh.oeaw.ac.at/oefosdiscipline...
# 3          Video  https://vocabs.sshopencloud.eu/vocabularies/me...
# 4           Text  https://vocabs.sshopencloud.eu/vocabularies/me...
#
#                                Comment
# 0  Sprach- und Literaturwissenschaften
# 1              Geschichte, Archäologie
# 2  Sprach- und Literaturwissenschaften
# 3                                video
# 4                                 text

# %% [markdown]
# ## 1 Look for vocabulary terms with the value from the column *Keyword to map*
#
# The function *getMPKeywordProperies(myKey)* is a custum function that uses the API entry
#
#     GET https://marketplace-api.sshopencloud.eu/api/concept-search?types=keyword&q=VALUE
#
# and returns the vocabulary terms for *myKey*.
#
# In the cell below, the returned dataset is filtered to individuate those values coming from the vocabulary *sshoc-keyword* (vocabulary[code]=sshoc-keyword), then the resulting dataset is shown.

# %%
#In this example the key value searched is the one in the rown of the google sheet
rown=0
myKey=df_keywords.iloc[rown]['Keyword to map']
df_vocterms=mpdata.getMPKeywordProperties(myKey)
df_vocterms=df_vocterms[df_vocterms.vocabulary=={'code': 'sshoc-keyword'}]
df_vocterms
# Out:
#                                                  code  \
# 0                                         Linguistics
# 1                                         linguistics
# 2                           computational-linguistics
# 3                              historical-linguistics
# 4                                  Corpus+linguistics
# 5                                linguistic-variation
# 6                                linguistic+resources
# 7         TEI+Lite+markup%2C+no+linguistic+annotation
# 8   +syntactically+parsed%3B+Swedish+subset%3A+no+...
# 9   Finnish+subset%3A+MSD-tagged%2C+syntactically+...
# 10                                   sociolinguistics
#
#                    vocabulary  \
# 0   {'code': 'sshoc-keyword'}
# 1   {'code': 'sshoc-keyword'}
# 2   {'code': 'sshoc-keyword'}
# 3   {'code': 'sshoc-keyword'}
# 4   {'code': 'sshoc-keyword'}
# 5   {'code': 'sshoc-keyword'}
# 6   {'code': 'sshoc-keyword'}
# 7   {'code': 'sshoc-keyword'}
# 8   {'code': 'sshoc-keyword'}
# 9   {'code': 'sshoc-keyword'}
# 10  {'code': 'sshoc-keyword'}
#
#                                                 label     notation  \
# 0                                         Linguistics  Linguistics
# 1                                         linguistics
# 2                           computational-linguistics
# 3                              historical-linguistics
# 4                                  Corpus linguistics
# 5                                linguistic-variation
# 6                                linguistic resources
# 7           TEI Lite markup, no linguistic annotation
# 8    syntactically parsed; Swedish subset: no ling...
# 9   Finnish subset: MSD-tagged, syntactically pars...
# 10                                   sociolinguistics
#
#                                                   uri                  types  \
# 0   https://vocabs.dariah.eu/sshoc-keyword/Linguis...  [{'code': 'keyword'}]
# 1   https://vocabs.dariah.eu/sshoc-keyword/linguis...  [{'code': 'keyword'}]
# 2   https://vocabs.dariah.eu/sshoc-keyword/computa...  [{'code': 'keyword'}]
# 3   https://vocabs.dariah.eu/sshoc-keyword/histori...  [{'code': 'keyword'}]
# 4   https://vocabs.dariah.eu/sshoc-keyword/Corpus+...  [{'code': 'keyword'}]
# 5   https://vocabs.dariah.eu/sshoc-keyword/linguis...  [{'code': 'keyword'}]
# 6   https://vocabs.dariah.eu/sshoc-keyword/linguis...  [{'code': 'keyword'}]
# 7   https://vocabs.dariah.eu/sshoc-keyword/TEI+Lit...  [{'code': 'keyword'}]
# 8   https://vocabs.dariah.eu/sshoc-keyword/+syntac...  [{'code': 'keyword'}]
# 9   https://vocabs.dariah.eu/sshoc-keyword/Finnish...  [{'code': 'keyword'}]
# 10  https://vocabs.dariah.eu/sshoc-keyword/socioli...  [{'code': 'keyword'}]
#
#     candidate
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
# 5       False
# 6        True
# 7        True
# 8        True
# 9        True
# 10      False

# %% [markdown]
# The set of vocabulary terms is filterd to individuate those with the exact match (case-insensitive)

# %%
df_vocterms=df_vocterms[(df_vocterms.code).str.lower()==myKey.lower()]
df_vocterms
# Out:
#           code                 vocabulary        label     notation  \
# 0  Linguistics  {'code': 'sshoc-keyword'}  Linguistics  Linguistics
# 1  linguistics  {'code': 'sshoc-keyword'}  linguistics
#
#                                                  uri                  types  \
# 0  https://vocabs.dariah.eu/sshoc-keyword/Linguis...  [{'code': 'keyword'}]
# 1  https://vocabs.dariah.eu/sshoc-keyword/linguis...  [{'code': 'keyword'}]
#
#    candidate
# 0       True
# 1      False

# %% [markdown]
# ## 2 Look for the term in the column *Map to*
#
# The function *getMPConcepts()* is a custum function that uses the API entry:
#
# GET https://marketplace-api.sshopencloud.eu/api/concept-search?perpage=100&q=URI
#
# to get all the *concepts* from the MarketPlace dataset.
#
# **Note that executing this function may require some time, currently 14995 records are returned**

# %%
df_concepts=mpdata.getMPConcepts()
df_concepts.count()
# Out:
# code          14995
# vocabulary    14995
# label         14995
# notation      14995
# uri           14995
# types         14995
# candidate     14995
# definition      209
# dtype: int64

# %% [markdown]
# a look at few of the returned records

# %%
df_concepts.tail()
# Out:
#                     code                 vocabulary              label  \
# 14990         +CR-tagged  {'code': 'sshoc-keyword'}          CR-tagged
# 14991         ID-glosses  {'code': 'sshoc-keyword'}         ID-glosses
# 14992               +WSD  {'code': 'sshoc-keyword'}                WSD
# 14993  paragraph+aligned  {'code': 'sshoc-keyword'}  paragraph aligned
# 14994          +PoS+tags  {'code': 'sshoc-keyword'}           PoS tags
#
#       notation                                                uri  \
# 14990           https://vocabs.dariah.eu/sshoc-keyword/+CR-tagged
# 14991           https://vocabs.dariah.eu/sshoc-keyword/ID-glosses
# 14992                 https://vocabs.dariah.eu/sshoc-keyword/+WSD
# 14993           https://vocabs.dariah.eu/sshoc-keyword/paragra...
# 14994            https://vocabs.dariah.eu/sshoc-keyword/+PoS+tags
#
#                        types  candidate definition
# 14990  [{'code': 'keyword'}]       True        NaN
# 14991  [{'code': 'keyword'}]       True        NaN
# 14992  [{'code': 'keyword'}]       True        NaN
# 14993  [{'code': 'keyword'}]       True        NaN
# 14994  [{'code': 'keyword'}]       True        NaN

# %% [markdown]
# Search for the one concept that has in the *uri* attribute (or column) the value of the *Map to*. There should be only one such concept.

# %%
test3=df_concepts[df_concepts.uri==df_keywords.iloc[rown]['Map to']]
test3.head()
# Out:
#        code              vocabulary                       label notation  \
# 14031  6020  {'code': 'discipline'}  Linguistics and Literature     6020
#
#                                                      uri  \
# 14031  https://vocabs.acdh.oeaw.ac.at/oefosdiscipline...
#
#                           types  candidate definition
# 14031  [{'code': 'discipline'}]      False        NaN

# %% [markdown]
# The attribute *types* contains the value of the type code

# %% [markdown]
# ## 3 Go through all MP items to look for the *keywords-to-map* in the keyword-dynamic-property
#
# For this we use the *getAllPropertiesBySources()* custom functions that returns all dynamic properties; for every property it is reported also the main attributes and the PID of the item whom it belongs.

# %%
utils=hel.Util()
resultfields=['MPUrl', 'category', 'label', 'type.code', 'type.label', 'concept.code', 'concept.label', 'concept.uri', 'concept.vocabulary.scheme']
udf_alprop=utils.getAllPropertiesBySources()
udf_alprop=udf_alprop[resultfields]

# %% [markdown]
# Filter the dataset using the *Keyword to Map* and show the result (or part of the result)

# %%
udf_alprop.reset_index(inplace=True)
udf_alprop[udf_alprop['concept.label'].str.lower()==myKey.lower()].head()
# Out:
#       index                   MPUrl         category  \
# 373     373  tool-or-service/IJjaNl  tool-or-service
# 1404   1404  tool-or-service/pC5SBh  tool-or-service
# 2617   2617  tool-or-service/KE90xs  tool-or-service
# 3257   3257  tool-or-service/wa0xoI  tool-or-service
# 4207   4207  tool-or-service/3m4luN  tool-or-service
#
#                                                   label type.code type.label  \
# 373   An alpha version of a lexicographical platform...   keyword    Keyword
# 1404                         brat rapid annotation tool   keyword    Keyword
# 2617                                     CorpusExplorer   keyword    Keyword
# 3257                                            DEREDEC   keyword    Keyword
# 4207  EURAC: Extended Linguistic Dependency Diagrams...   keyword    Keyword
#
#      concept.code concept.label  \
# 373   linguistics   linguistics
# 1404  linguistics   linguistics
# 2617  linguistics   linguistics
# 3257  linguistics   linguistics
# 4207  linguistics   linguistics
#
#                                             concept.uri  \
# 373   https://vocabs.dariah.eu/sshoc-keyword/linguis...
# 1404  https://vocabs.dariah.eu/sshoc-keyword/linguis...
# 2617  https://vocabs.dariah.eu/sshoc-keyword/linguis...
# 3257  https://vocabs.dariah.eu/sshoc-keyword/linguis...
# 4207  https://vocabs.dariah.eu/sshoc-keyword/linguis...
#
#                           concept.vocabulary.scheme
# 373   https://vocabs.dariah.eu/sshoc-keyword/Schema
# 1404  https://vocabs.dariah.eu/sshoc-keyword/Schema
# 2617  https://vocabs.dariah.eu/sshoc-keyword/Schema
# 3257  https://vocabs.dariah.eu/sshoc-keyword/Schema
# 4207  https://vocabs.dariah.eu/sshoc-keyword/Schema

# %% [markdown]
# To be completed
