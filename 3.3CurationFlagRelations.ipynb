# %% [markdown]
# # Notebook 3.3 - Curation-flag-relation
#
# This notebook analyses the relations between items of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-relation` and `curation-detail` properties.
#
# This notebook flags Marketplace items for which contextualisation quality is low (based on interlinked items), helping Moderators improve the relations between items.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 3 sections:
#
# 0. Requirements to run the notebook
# 1. Check the number of relations per item
# 2. Flag items with not enough relations

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel
utils=hel.Util()

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
#df_all_items.iloc[1].relatedItems

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'description', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 305  12634       l8gLBb  dataset
# 306  12631       xvYQQ4  dataset
# 307  12632       IdZGtV  dataset
# 308  12633       OMny6U  dataset
# 309  12589       YnEaU0  dataset
#
#                                                  label  \
# 305                    Yelp Academic Challenge Dataset
# 306                                            YelpCHI
# 307                                            YelpNYC
# 308                                            YelpZIP
# 309  "You Are Where You Tweet: A Content-Based Appr...
#
#                                            description  \
# 305  The Yelp dataset is a subset of our businesses...
# 306  This dataset is collected from Yelp.com and fi...
# 307  This dataset is collected from Yelp.com and fi...
# 308  This dataset is collected from Yelp.com and fi...
# 309  This dataset is a collection of scraped public...
#
#                                           contributors  \
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 308  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 309  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 305                    [https://www.yelp.com/dataset]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 307  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 308  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 309   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check the number of relations per item
#
# By default, and according to rules set up in the Editorial Guidelines, items in the SSH Open Marketplace should be interlinked.

# %%
df_rel_it=utils.getAllRelatedItems()
df_rel_it.sort_values('label').head()
# Out:
#     item_persistentId    item_category       item_label   relation.label  \
# 336            gNfOzz  tool-or-service          YouTube  Is mentioned in
# 273            h2MFPS  tool-or-service  TEI Boilerplate       Relates to
# 149            gHCDwq  tool-or-service           Kindle  Is mentioned in
# 208            Ov8Pwn  tool-or-service            Omeka  Is mentioned in
# 136            Px3QPk  tool-or-service         InDesign  Is mentioned in
#
#     persistentId     category  \
# 336       rSRIZx  publication
# 273       UK7Sij  publication
# 149       q0d7jU  publication
# 208       rhl8Z2  publication
# 136       MEJQbE  publication
#
#                                                  label workflowId  \
# 336  "My Name is Lizzie Bennet - " Reading, Partici...        NaN
# 273  "On the record" - transcribing and valorizing ...        NaN
# 149             A Scholarly Edition for Mobile Devices        NaN
# 208                              A Seat At "La Tawola"        NaN
# 136  A World of Difference - Myths and misconceptio...        NaN
#
#                                            description    relation.code
# 336                            No description provided  is-mentioned-in
# 273  Qualitative interviews constitute an important...       relates-to
# 149                            No description provided  is-mentioned-in
# 208                            No description provided  is-mentioned-in
# 136                            No description provided  is-mentioned-in

# %%
# df_rel_it.shape

# %% [markdown]
# The following cell code returns a dataframe with all the items having 3 related items, it uses the function __getRelateditems (itemcategories, operator, nrelitems)__  returns a dataframe with items in a specific category having related items.
# The parameters are:
#
# <ul>
#     <li>categories: the list of categories. This parameter is mandatory, if the search should be done in all categories the keyword *all* can be used</li>
#     <li> the operator.  Optional, accepted values are =, &lt; and &gt; (the default) </li>
#     <li> nrelitems: an optional parameter, if not present all items are returned.</li>
# </ul>
#
# *Warning: the development of the function getRelatedItems is in progress*

# %%
df_test_ri=utils.getRelatedItems('all', '<',1)
df_test_ri.head()
# Out:
#                 MPUrl persistentId     category  \
# 0      dataset/soZi7a       soZi7a      dataset
# 1  publication/kqQFjG       kqQFjG  publication
# 2  publication/PTeiK8       PTeiK8  publication
# 3  publication/lVUU0N       lVUU0N  publication
# 4      dataset/PODPq9       PODPq9      dataset
#
#                                                label relatedItems  value
# 0  "A BLAST-based, Language-agnostic Text Reuse A...           []      0
# 1  "A Model for International Cooperation - Emble...           []      0
# 2  "A Pale Reflection of the Violent Truth? Pract...           []      0
# 3  "A Trace of this Journey" - Citations of Digit...           []      0
# 4       "A Visual Style in Two Network Sitcoms" data           []      0

# %%
df_test_ri=utils.getRelatedItems('all', '=',2)
df_test_ri.head()
# Out:
#                     MPUrl persistentId         category  \
# 0  tool-or-service/isedTr       isedTr  tool-or-service
# 1  tool-or-service/isedTr       isedTr  tool-or-service
# 2      publication/Ja3t2z       Ja3t2z      publication
# 3      publication/Ja3t2z       Ja3t2z      publication
# 4  tool-or-service/r43yWg       r43yWg  tool-or-service
#
#                                                label   relation.label  \
# 0                                  Agisoft Metashape  Is mentioned in
# 1                                  Agisoft Metashape  Is mentioned in
# 2  An update on automatic transcription vs. manua...         Mentions
# 3  An update on automatic transcription vs. manua...         Mentions
# 4                                     Apache OpenNLP  Is mentioned in
#
#   relitem_persistentId relItem_category  \
# 0               R6XaVm             step
# 1               Vb1dhh             step
# 2               cIP0cd  tool-or-service
# 3               gNfOzz  tool-or-service
# 4               s89flK             step
#
#                                        relItem_label  \
# 0  Data processing: Create a 3D model of the site...
# 1  Georeferencing the surveyed data: Using a GNSS...
# 2                                    Mozilla Firefox
# 3                                            YouTube
# 4                     Using an existing NLP pipeline
#
#                                  relItem_description    relation.code  value  \
# 0  This step is related to the surveyed object an...  is-mentioned-in      2
# 1  Using well materialized Ground Control Points ...  is-mentioned-in      2
# 2            http://www.wikidata.org/entity/Q3866728         mentions      2
# 3           http://www.wikidata.org/entity/Q16971117         mentions      2
# 4  In practice, the above steps are combined to p...  is-mentioned-in      2
#
#   workflowId
# 0     wqeZGu
# 1     wqeZGu
# 2        NaN
# 3        NaN
# 4     x1hL0m

# %%
df_test_ri['property']='relations'
df_test_ri_no_duplicates=df_test_ri.drop_duplicates(subset=['label'], keep='first')
df_test_ri_no_duplicates.head()

# %% [markdown]
# ## 2. Flag items with with not enough relations

# %%
curation_flag_property={"code": "curation-flag-relations"}
curation_detail_property={"code": "curation-detail"}

# %%
res_des=mpdata.setPropertyFlags(df_test_ri_no_duplicates, curation_flag_property, curation_detail_property)
