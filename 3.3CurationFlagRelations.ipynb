# %% [markdown]
# # Notebook 3.3 - Curation-flag-relation
#
# This notebook analyses the relations between items of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-relation` and `curation-detail` properties.
#
# This notebook flags Marketplace items for which contextualisation quality is low (based on interlinked items), helping Moderators improve the relations between items.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 3 sections:
#
# 0. Requirements to run the notebook
# 1. Check the number of relations per item
# 2. Flag items with not enough relations

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel
utils=hel.Util()

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  45953  tool-or-service                                             140kit
# 1  49576  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  49577  tool-or-service                                              3DHOP
# 3  49578  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  49579  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       3IAyEp  2021-07-30T16:03:01+0000  approved
# 1       U3gQrh  2021-09-22T15:51:38+0000  approved
# 2       MnpOWX  2021-09-22T15:51:39+0000  approved
# 3       gA7zFN  2021-09-22T15:51:39+0000  approved
# 4       Q49CiV  2021-09-22T15:51:40+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1                           No description provided.
# 2                           No description provided.
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 483, 'name': 'Ian Pearce, De...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'activity', 'label': 'Activ...          []  ...
# 1  [{'type': {'code': 'curation-flag-description'...          []  ...
# 2  [{'type': {'code': 'curation-flag-description'...          []  ...
# 3  [{'type': {'code': 'curation-flag-description'...          []  ...
# 4  [{'type': {'code': 'curation-flag-description'...          []  ...
#
#   thumbnail.info.filename thumbnail.info.mimeType thumbnail.info.hasThumbnail  \
# 0      acdh-ch-logo96.png               image/png                        True
# 1                     NaN                     NaN                         NaN
# 2                     NaN                     NaN                         NaN
# 3                     NaN                     NaN                         NaN
# 4                     NaN                     NaN                         NaN
#
#                         thumbnail.caption  version  \
# 0  test thumbnail of uploaded media image      NaN
# 1                                     NaN      NaN
# 2                                     NaN      NaN
# 3                                     NaN      NaN
# 4                                     NaN      NaN
#
#   thumbnail.info.location.sourceUrl informationContributor.email dateCreated  \
# 0                               NaN                          NaN         NaN
# 1                               NaN                          NaN         NaN
# 2                               NaN                          NaN         NaN
# 3                               NaN                          NaN         NaN
# 4                               NaN                          NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 37 columns]

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'description', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 303  12634       l8gLBb  dataset
# 304  12631       xvYQQ4  dataset
# 305  12632       IdZGtV  dataset
# 306  12633       OMny6U  dataset
# 307  12589       YnEaU0  dataset
#
#                                                  label  \
# 303                    Yelp Academic Challenge Dataset
# 304                                            YelpCHI
# 305                                            YelpNYC
# 306                                            YelpZIP
# 307  "You Are Where You Tweet: A Content-Based Appr...
#
#                                            description  \
# 303  The Yelp dataset is a subset of our businesses...
# 304  This dataset is collected from Yelp.com and fi...
# 305  This dataset is collected from Yelp.com and fi...
# 306  This dataset is collected from Yelp.com and fi...
# 307  This dataset is a collection of scraped public...
#
#                                           contributors  \
# 303  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 304  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 303                    [https://www.yelp.com/dataset]  Humanities Data
# 304  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 305  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 307   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check the number of relations per item
#
# By default, and according to rules set up in the Editorial Guidelines, items in the SSH Open Marketplace should be interlinked.

# %%
df_rel_it=utils.getAllRelatedItems()
df_rel_it.sort_values('label').head()
# Out:
#      item_persistentId    item_category  \
# 235             h8UTUS  tool-or-service
# 313             iQdKk2  tool-or-service
# 171             ip7fwu  tool-or-service
# 1042            CduoOq  tool-or-service
# 465             dvJSDD  tool-or-service
#
#                                              item_label   relation.label  \
# 235   Ethnic and Migrant Minorities (EMM) Survey Reg...    Is related to
# 313                                               Gephi    Is related to
# 171                                            DH Press  Is mentioned in
# 1042                                              Skype  Is mentioned in
# 465                                        Google Books  Is mentioned in
#
#      persistentId         category  \
# 235        4SVucl  tool-or-service
# 313        4SVucl  tool-or-service
# 171        t6q6FW      publication
# 1042       BNGWfl      publication
# 465        GIb2N9      publication
#
#                                                   label workflowId  \
# 235                         Automated Verification Tool        NaN
# 313                         Automated Verification Tool        NaN
# 171   "A Pale Reflection of the Violent Truth? Pract...        NaN
# 1042  "A picture is worth a thousand words"? - From ...        NaN
# 465   "Inventing the Map - " from 19th-century Pedag...        NaN
#
#                                             description    relation.code
# 235   The Automatic Verification Tool (AVT) enables ...    is-related-to
# 313   The Automatic Verification Tool (AVT) enables ...    is-related-to
# 171                            No description provided.  is-mentioned-in
# 1042                           No description provided.  is-mentioned-in
# 465                             No description provided  is-mentioned-in

# %%
df_rel_it.shape
# Out:
# (1766, 10)

# %% [markdown]
# The following cell code returns a dataframe with all the items having 3 related items, it uses the function __getRelateditems (itemcategories, operator, nrelitems)__  returns a dataframe with items in a specific category having related items.
# The parameters are:
#
# <ul>
#     <li>categories: the list of categories. This parameter is mandatory, if the search should be done in all categories the keyword *all* can be used</li>
#     <li> the operator.  Optional, accepted values are =, &lt; and &gt; (the default) </li>
#     <li> nrelitems: an optional parameter, if not present all items are returned.</li>
# </ul>

# %%
df_test_ri=utils.getRelatedItems('all', '<', 3)
df_test_ri.head(7)
# Out:
#                       MPUrl persistentId           category  \
# 0    tool-or-service/4SVucl       4SVucl    tool-or-service
# 1    tool-or-service/4SVucl       4SVucl    tool-or-service
# 2        publication/rSRIZx       rSRIZx        publication
# 3        publication/UK7Sij       UK7Sij        publication
# 4  training-material/baDTwh       baDTwh  training-material
# 5    tool-or-service/U3gQrh       U3gQrh    tool-or-service
# 6  training-material/T3JbA2       T3JbA2  training-material
#
#                                                label   relation.label  \
# 0                        Automated Verification Tool       Relates to
# 1                        Automated Verification Tool       Relates to
# 2  "My Name is Lizzie Bennet - " Reading, Partici...         Mentions
# 3  "On the record" - transcribing and valorizing ...    Is related to
# 4  2.1 Error rates and ground truth - Text Digiti...  Is mentioned in
# 5  3DF Zephyr - photogrammetry software - 3d mode...  Is mentioned in
# 6                                     3DHOP - How To  Is mentioned in
#
#   relitem_persistentId relItem_category  \
# 0               h8UTUS  tool-or-service
# 1               iQdKk2  tool-or-service
# 2               gNfOzz  tool-or-service
# 3               h2MFPS  tool-or-service
# 4               KEugTm             step
# 5               pXppX6             step
# 6               mSWgiF             step
#
#                                        relItem_label  \
# 0  Ethnic and Migrant Minorities (EMM) Survey Reg...
# 1                                              Gephi
# 2                                            YouTube
# 3                                    TEI Boilerplate
# 4                Test on a subset and assess quality
# 5     Acquisition of a 3D object (by photogrammetry)
# 6                                      Visualisation
#
#                                  relItem_description    relation.code  value  \
# 0  The EMM Survey Registry—which has been co-crea...       relates-to      2
# 1  Gephi is the leading visualization and explora...       relates-to      2
# 2           http://www.wikidata.org/entity/Q16971117         mentions      1
# 3  TEI Boilerplate is a lightweight solution for ...    is-related-to      1
# 4  The first step to take is the definition of a ...  is-mentioned-in      1
# 5  The photogrammetry method relies on a\n       ...  is-mentioned-in      1
# 6  Visualize 3D models requires specific (web-bas...  is-mentioned-in      1
#
#   workflowId
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4     qYzKVU
# 5     MHUaGI
# 6     B3V0jJ

# %%
df_test_ri['property']='relations'
df_test_ri_no_duplicates=df_test_ri[df_test_ri.duplicated(subset=['label'], keep='first')]

# %% [markdown]
# ## 2. Flag items with with not enough relations

# %%
curation_flag_property={"code": "curation-flag-relations"}
curation_detail_property={"code": "curation-detail"}

# %%
res_des=mpdata.setPropertyFlags(df_test_ri_no_duplicates, curation_flag_property, curation_detail_property)
# Out:
# Creating log file...
# The property: relations, has value 1, in item with pid: tools/m9q6vc, (current version: 43477)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "1"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/n0cSzL, (current version: 63339)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/d2HMjC, (current version: 61434)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/5v0M24, (current version: 63438)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/iJHK6Q, (current version: 49587)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/RUZe3g, (current version: 62065)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/JKGhtG, (current version: 62032)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/4SVucl, (current version: 49905)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/mToGiG, (current version: 49596)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/mvAuo9, (current version: 45345)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/7vkKr2, (current version: 61630)
# {"url": [{"accessibleAt": "503"}], "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/i7Ah2U, (current version: 61497)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/oM2qv9, (current version: 49609)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/teNZSt, (current version: 63084)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/khUtdK, (current version: 61741)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/5IRWwi, (current version: 62029)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/8aoLzE, (current version: 54268)
# {"url": [{"accessibleAt": "404"}], "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/QWpvau, (current version: 61754)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/GHlkFz, (current version: 49633)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/Ji5s9J, (current version: 62923)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/FvtNkF, (current version: 62514)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/G05k3l, (current version: 61520)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/umj6Lg, (current version: 56468)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/6vZOfG, (current version: 56950)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/JTi8mw, (current version: 62706)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/ymydPK, (current version: 63445)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/rJ5Hqz, (current version: 62661)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/lwXTCA, (current version: 61850)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/WfhTvQ, (current version: 49683)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/tmCX0Z, (current version: 61682)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/FLK4Bl, (current version: 63411)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/d7T7Un, (current version: 62486)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/YmnOEu, (current version: 63345)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/N2DBHn, (current version: 55478)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/5yweb6, (current version: 49696)
# The property: relations, has value 2, in item with pid: tools/5yweb6, (current version: 49696)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/aZ99Rw, (current version: 62381)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/Bt7BX4, (current version: 49701)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/TFVbcI, (current version: 62262)
# The property: relations, has value 2, in item with pid: tools/TFVbcI, (current version: 62262)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/MTIBoJ, (current version: 61436)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/TnfNf3, (current version: 54110)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/aaq3fD, (current version: 61655)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/orjfXo, (current version: 55116)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/IV2Rgd, (current version: 49718)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/O2TBOZ, (current version: 62576)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/fmVaW7, (current version: 63352)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/K5js1D, (current version: 61576)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/5TuvTT, (current version: 63386)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/XNzmtl, (current version: 62671)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/fPLpV3, (current version: 54417)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/QX9TKA, (current version: 63452)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/oU3FjR, (current version: 62357)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/dbGwJK, (current version: 49763)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/f0G4GI, (current version: 61419)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/RX5XdB, (current version: 62978)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/fnRO5e, (current version: 49773)
# {"description": {"length": "0"}, "relations": "{\"length\": \"2\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/QQd3D5, (current version: 58001)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 1, in item with pid: tools/HQjxLh, (current version: 49774)
# {"description": {"length": "0"}, "relations": "{\"length\": \"1\"}"}
# append curation_property_value
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/MkELgr, (current version: 45876)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/eqVSrT, (current version: 63266)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/wwZCSd, (current version: 63080)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/eAy9zP, (current version: 63294)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/65uQpg, (current version: 63354)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/oda27K, (current version: 63361)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/iy9UL6, (current version: 62852)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/onidM5, (current version: 54710)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: tools/sGLPyd, (current version: 61665)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [200]>
# The property: relations, has value 2, in item with pid: publications/Ja3t2z, (current version: 40185)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/eaqXEQ, (current version: 36282)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/NyLFGF, (current version: 36939)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/iEgj71, (current version: 36945)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/6kYac0, (current version: 36948)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/I0TnYt, (current version: 36885)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/CUDWnT, (current version: 36525)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/VWAuuT, (current version: 36102)
# The property: relations, has value 2, in item with pid: publications/VWAuuT, (current version: 36102)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/gP6avY, (current version: 36888)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/vIkR3Q, (current version: 36894)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/GX5ERg, (current version: 36891)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/KZAW1u, (current version: 36450)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/Ev43G3, (current version: 40250)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/wAoWEu, (current version: 40282)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/Xo6GPy, (current version: 36453)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/6hXXvy, (current version: 36435)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/GuyjGt, (current version: 36147)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/8NGiHu, (current version: 36702)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/H56uhw, (current version: 36852)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/1Rmxc4, (current version: 40407)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/QyVRx2, (current version: 35913)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/7rX6ht, (current version: 36438)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/OEJRGr, (current version: 36075)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/HqdBbP, (current version: 36369)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/4jQvZ5, (current version: 36855)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: publications/MNtoS6, (current version: 36336)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/ARPZXa, (current version: 36882)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 1, in item with pid: trainingMaterials/KbYQxy, (current version: 36300)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "1"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/dEKR6G, (current version: 36942)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/21muUk, (current version: 36456)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/ZV6GEg, (current version: 36468)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/dro7ts, (current version: 36936)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# The property: relations, has value 2, in item with pid: trainingMaterials/bxWKhV, (current version: 36951)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"relations": {"length": "2"}}'}
# updating item...
# <Response [404]>
# Reloading data from MP server, please wait...
# done!
