# %% [markdown]
# # Notebook 3.1 - Curation-flag-URL
#
# This notebook analyses the URL-based fields of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-url` and `curation-detail` properties.
#
# This notebook flags Marketplace items that have errors in their URL-based fields, helping Moderators identify curation priorities to improve data quality.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 4 sections:
#
# 0. Requirements to run the notebook
# 1. Check & flag error values in `accessibleAt`
# 2. Check & flag error values in URL-based properties
# 3. Check & flag error values in URL-based properties for a given source - example

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data
#
# df_all_items.head() will show the first 5 rows of the dataframe
#
# df_all_items.tail() will show the 5 last rows of the dataframe
#
# df_all_items.shape will give the dataframe shape (number of rows and columns)

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  45163  tool-or-service                                             140kit
# 1  36324  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  48611  tool-or-service                                              3DHOP
# 3  42055  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  42056  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       SIU1nO  2022-10-27T16:29:58+0000  approved
# 1       4gDAHv  2022-01-13T11:49:02+0000  approved
# 2       UcxOmD  2022-11-04T09:34:17+0000  approved
# 3       uFIMPQ  2022-09-12T16:59:36+0000  approved
# 4       kAkzuz  2022-09-12T16:59:36+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1  3DF Zephyr\[1\]\[2\] is a commercial photogram...
# 2  3DHOP (3D Heritage Online Presenter) is an ope...
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 2224, 'name': 'Ian Pearce, D...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'mode-of-use', 'label': 'Mo...          []  ...
# 1  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 2  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 3  [{'type': {'code': 'curation-flag-description'...          []  ...
# 4  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
#
#   thumbnail.info.mediaId thumbnail.info.category thumbnail.info.filename  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#   thumbnail.info.mimeType  thumbnail.info.hasThumbnail  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#   thumbnail.info.location.sourceUrl thumbnail.caption dateCreated  \
# 0                               NaN               NaN         NaN
# 1                               NaN               NaN         NaN
# 2                               NaN               NaN         NaN
# 3                               NaN               NaN         NaN
# 4                               NaN               NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# `df_all_items_work` selects the columns/attributes of interest

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#          id persistentId category  \
# 1139  49109       gKJuvx  dataset
# 1140  12589       YnEaU0  dataset
# 1141  49297       x2xkU7  dataset
# 1142  49595       fT0AeP  dataset
# 1143  49408       ekoDXk  dataset
#
#                                                   label  \
# 1139  York-Helsinki Parsed Corpus of Old English Poetry
# 1140  "You Are Where You Tweet: A Content-Based Appr...
# 1141                    Zurich English Newspaper Corpus
# 1142  Zweite Generation deutschsprachiger Migranten ...
# 1143                                             μtopia
#
#                                            contributors  \
# 1139                                                 []
# 1140  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 1141                                                 []
# 1142                                                 []
# 1143                                                 []
#
#                                            accessibleAt  \
# 1139          [http://hdl.handle.net/20.500.12024/2425]
# 1140    [https://archive.org/details/twitter_cikm_2010]
# 1141  [http://www.helsinki.fi/varieng/CoRD/corpora/Z...
# 1142  [http://hdl.handle.net/10932/00-0332-C453-CEDC...
# 1143  [http://www.cs.cmu.edu/~lingwang/microtopia/#o...
#
#                   source.label
# 1139  CLARIN Resource Families
# 1140           Humanities Data
# 1141  CLARIN Resource Families
# 1142  CLARIN Resource Families
# 1143  CLARIN Resource Families

# %% [markdown]
# ## 1. Check & flag values in `accessibleAt`
#
# `accessibleAt` is the main URL field of MP items.
#
# The following cell checks if there are empty values in `accessibleAt` for all items

# %%
df_all_items_work_emptyurls=df_all_items_work[df_all_items_work['accessibleAt'].str.len()==0]

emptyurldescriptionsn=df_all_items_work_emptyurls.count()[0]

print(f'\n There are {emptyurldescriptionsn} items without accessibleAt URLs\n')
# Out:
#  There are 564 items without accessibleAt URLs

# %% [markdown]
# ### 1.1 Check the validity of URLs in the accessibleAt property using the HTTP Result Status code
#
# The code below explicitly execute an http call for every URL, waits for the [Result Status Code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) of the call and then registers the code.
# Depending on connections and server answer times it may take several minutes to process all URLs.

# %%
#The list of categories is defined in the following statement

categories="toolsandservices, publications, trainingmaterials, workflows, datasets"

check=eva.URLCheck()
df_urls=check.checkURLValues(categories, 'accessibleAt')
df_urls.head()
# Out:
# inspecting accessibleAt
#                     MPUrl persistentId         category  \
# 0  tool-or-service/SIU1nO       SIU1nO  tool-or-service
# 1  tool-or-service/4gDAHv       4gDAHv  tool-or-service
# 2  tool-or-service/UcxOmD       UcxOmD  tool-or-service
# 3  tool-or-service/uFIMPQ       uFIMPQ  tool-or-service
# 4  tool-or-service/kAkzuz       kAkzuz  tool-or-service
#
#                                                label      property  \
# 0                                             140kit  accessibleAt
# 1  3DF Zephyr - photogrammetry software - 3d mode...  accessibleAt
# 2                                              3DHOP  accessibleAt
# 3                3DHOP: 3D Heritage Online Presenter  accessibleAt
# 4                           3DReshaper \| 3DReshaper  accessibleAt
#
#                                                  url status
# 0        https://github.com/WebEcologyProject/140kit    200
# 1  https://www.3dflow.net/3df-zephyr-pro-3d-model...    200
# 2                      http://vcg.isti.cnr.it/3dhop/    200
# 3            https://github.com/cnr-isti-vclab/3DHOP    200
# 4                     https://www.3dreshaper.com/en/    200

# %%
df_urls.drop_duplicates(keep='first', inplace=True)
#df_urls.head()

# %%
utils=hel.Util()
df_http_status_nf_err=df_urls[df_urls['status'] == 404].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_http_status_serv_err=df_urls[df_urls['status'] == 200].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_http_status_err=pd.concat([df_http_status_nf_err, df_http_status_serv_err])
#df_http_status_err=df_urls.sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
#df_http_status_err.to_pickle('data/urlstatus.pickle')
#df_http_status_nf_err.to_pickle('data/urlstatus404.pickle')
myclickable_table = df_http_status_nf_err.style.format({'MPUrl': utils.make_clickable})
myclickable_table
# Out:
# <style  type="text/css" >
# </style><table id="T_a2965bae_a94c_11ed_939b_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MPUrl</th>        <th class="col_heading level0 col1" >persistentId</th>        <th class="col_heading level0 col2" >category</th>        <th class="col_heading level0 col3" >label</th>        <th class="col_heading level0 col4" >property</th>        <th class="col_heading level0 col5" >url</th>        <th class="col_heading level0 col6" >status</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row0" class="row_heading level0 row0" >5058</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col0" class="data row0 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/training-material/0y7yIY">training-material/0y7yIY</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col1" class="data row0 col1" >0y7yIY</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col2" class="data row0 col2" >training-material</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col3" class="data row0 col3" >Techniques d'anonymisation</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col4" class="data row0 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col5" class="data row0 col5" >http://journal-sfds.fr/index.php/stat_soc/article/view/398</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row0_col6" class="data row0 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row1" class="row_heading level0 row1" >1310</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col0" class="data row1 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/1vuuAw">tool-or-service/1vuuAw</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col1" class="data row1 col1" >1vuuAw</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col2" class="data row1 col2" >tool-or-service</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col3" class="data row1 col3" >test merge url</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col4" class="data row1 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col5" class="data row1 col5" >https://acdh.oeaw.ac.at/isl/testurl</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row1_col6" class="data row1 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row2" class="row_heading level0 row2" >1520</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col0" class="data row2 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/25grr1">tool-or-service/25grr1</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col1" class="data row2 col1" >25grr1</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col2" class="data row2 col2" >tool-or-service</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col3" class="data row2 col3" >VLE - Viennese Lexicographic Editor</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col4" class="data row2 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col5" class="data row2 col5" >https://www.oeaw.ac.at/en/acdh/tools/vle/</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row2_col6" class="data row2 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row3" class="row_heading level0 row3" >278</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col0" class="data row3 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/2YMYaD">tool-or-service/2YMYaD</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col1" class="data row3 col1" >2YMYaD</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col2" class="data row3 col2" >tool-or-service</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col3" class="data row3 col3" >DocuBurst</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col4" class="data row3 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col5" class="data row3 col5" >http://vialab.science.uoit.ca/portfolio/docuburst</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row3_col6" class="data row3 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row4" class="row_heading level0 row4" >6497</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col0" class="data row4 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/dataset/3W5E6J">dataset/3W5E6J</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col1" class="data row4 col1" >3W5E6J</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col2" class="data row4 col2" >dataset</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col3" class="data row4 col3" >Tübingen Treebank of Written German / Newspaper Corpus</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col4" class="data row4 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col5" class="data row4 col5" >http://www.sfs.uni-tuebingen.de/en/ascl/resources/corpora/tueba-dz.html</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row4_col6" class="data row4 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row5" class="row_heading level0 row5" >338</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col0" class="data row5 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/3ZpHvD">tool-or-service/3ZpHvD</a></td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col1" class="data row5 col1" >3ZpHvD</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col2" class="data row5 col2" >tool-or-service</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col3" class="data row5 col3" >Finding People or Characters from A Text (Named-Entity Recognition)</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col4" class="data row5 col4" >accessibleAt</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col5" class="data row5 col5" >https://github.com/TAPoR-3-Tools/Tapor-Coding-Tools/tree/master/tapor_coding_tools/natural%20language%20processing/Finging%20people%20or%20characters%20with%20NER</td>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row5_col6" class="data row5 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_a2965bae_a94c_11ed_939b_acde48001122level0_row6" class="row_heading level0 row6" >5779</th>
#                         <td id="T_a2965bae_a94c_11ed_939b_acde48001122row6_col0" cla

# %% [markdown]
# ## 2. Check & flag error values in URL-based properties

# %%
df_properties=utils.getProperties()
df_properties.head()
# Out:
#      type.code   type.label type.type  type.groupName  type.hidden  type.ord  \
# 0  mode-of-use  Mode of use   concept  Categorisation        False        22
# 1     activity     Activity   concept  Categorisation        False        17
# 2     activity     Activity   concept  Categorisation        False        17
# 3     activity     Activity   concept  Categorisation        False        17
# 4     activity     Activity   concept  Categorisation        False        17
#
#                             type.allowedVocabularies       concept.code  \
# 0  [{'code': 'invocation-type', 'scheme': 'https:...     webApplication
# 1  [{'code': 'tadirah2', 'scheme': 'https://vocab...          capturing
# 2  [{'code': 'tadirah2', 'scheme': 'https://vocab...  dataVisualization
# 3  [{'code': 'tadirah2', 'scheme': 'https://vocab...          analyzing
# 4  [{'code': 'tadirah2', 'scheme': 'https://vocab...          analyzing
#
#   concept.vocabulary.code                          concept.vocabulary.scheme  \
# 0         invocation-type  https://vocabs.sshopencloud.eu/vocabularies/in...
# 1                tadirah2                  https://vocabs.dariah.eu/tadirah/
# 2                tadirah2                  https://vocabs.dariah.eu/tadirah/
# 3                tadirah2                  https://vocabs.dariah.eu/tadirah/
# 4                tadirah2                  https://vocabs.dariah.eu/tadirah/
#
#    ... concept.vocabulary.closed       concept.label concept.notation  \
# 0  ...                      True     Web application
# 1  ...                      True           Capturing
# 2  ...                      True  Data Visualization
# 3  ...                      True           Analyzing
# 4  ...                      True           Analyzing
#
#                                          concept.uri concept.candidate  \
# 0  https://vocabs.sshopencloud.eu/vocabularies/in...             False
# 1         https://vocabs.dariah.eu/tadirah/capturing             False
# 2  https://vocabs.dariah.eu/tadirah/dataVisualiza...             False
# 3         https://vocabs.dariah.eu/tadirah/analyzing             False
# 4         https://vocabs.dariah.eu/tadirah/analyzing             False
#
#                                   concept.definition value   label  \
# 0                                                NaN   NaN  140kit
# 1                                                NaN   NaN  140kit
# 2  creation and study of the visual representatio...   NaN  140kit
# 3                                                NaN   NaN  140kit
# 4                                                NaN   NaN  140kit
#
#   persistentId         category
# 0       SIU1nO  tool-or-service
# 1       SIU1nO  tool-or-service
# 2       SIU1nO  tool-or-service
# 3       SIU1nO  tool-or-service
# 4       SIU1nO  tool-or-service
#
# [5 rows x 22 columns]

# %%
df_properties["type.type"].unique()
# Out:
# array(['concept', 'boolean', 'string', 'int', 'url', 'date', 'float'],
#       dtype=object)

# %%
df_properties_url=df_properties[df_properties["type.type"]=="url"]
df_properties_url
# Out:
#                 type.code          type.label type.type type.groupName  \
# 379              see-also            See also       url        Context
# 396              see-also            See also       url        Context
# 925       user-manual-url     User Manual URL       url        Context
# 926      terms-of-use-url    Terms of Use URL       url         Access
# 927    privacy-policy-url  Privacy policy URL       url         Access
# ...                   ...                 ...       ...            ...
# 40514            see-also            See also       url        Context
# 40529            see-also            See also       url        Context
# 40545            see-also            See also       url        Context
# 40546            see-also            See also       url        Context
# 40550            see-also            See also       url        Context
#
#        type.hidden  type.ord type.allowedVocabularies concept.code  \
# 379          False        28                      NaN          NaN
# 396          False        28                      NaN          NaN
# 925          False        29                      NaN          NaN
# 926          False         2                      NaN          NaN
# 927          False         6                      NaN          NaN
# ...            ...       ...                      ...          ...
# 40514        False        28                      NaN          NaN
# 40529        False        28                      NaN          NaN
# 40545        False        28                      NaN          NaN
# 40546        False        28                      NaN          NaN
# 40550        False        28                      NaN          NaN
#
#       concept.vocabulary.code concept.vocabulary.scheme  ...  \
# 379                       NaN                       NaN  ...
# 396                       NaN                       NaN  ...
# 925                       NaN                       NaN  ...
# 926                       NaN                       NaN  ...
# 927                       NaN                       NaN  ...
# ...                       ...                       ...  ...
# 40514                     NaN                       NaN  ...
# 40529                     NaN                       NaN  ...
# 40545                     NaN                       NaN  ...
# 40546                     NaN                       NaN  ...
# 40550                     NaN                       NaN  ...
#
#       concept.vocabulary.closed concept.label concept.notation concept.uri  \
# 379                         NaN           NaN              NaN         NaN
# 396                         NaN           NaN              NaN         NaN
# 925                         NaN           NaN              NaN         NaN
# 926                         NaN           NaN              NaN         NaN
# 927                         NaN           NaN              NaN         NaN
# ...                         ...           ...              ...         ...
# 40514                       NaN           NaN              NaN         NaN
# 40529                       NaN           NaN              NaN         NaN
# 40545                       NaN           NaN              NaN         NaN
# 40546                       NaN           NaN              NaN         NaN
# 40550                       NaN           NaN              NaN         NaN
#
#       concept.candidate concept.definition  \
# 379                 NaN                NaN
# 396                 NaN                NaN
# 925                 NaN                NaN
# 926                 NaN                NaN
# 927                 NaN                NaN
# ...                 ...                ...
# 40514               NaN                NaN
# 40529               NaN                NaN
# 40545               NaN                NaN
# 40546               NaN                NaN
# 40550               NaN                NaN
#
#                                                    value  \
# 379    https://www.dariah.eu/tools-services/tools-and...
# 396                            http://www.hiu.cas.cz/cs/
# 925    https://du.cesnet.cz/en/navody/object_storage/...
# 926      https://du.cesnet.cz/en/provozni_pravidla/start
# 927    https://www.cesnet.cz/cesnet/personal-data-pro...
# ...                                                  ...
# 40514                http://stnt.ijp.pan.pl/idxlac/index
# 40529            http://hdl.handle.net/20.500.12024/2425
# 40545  http://hdl.handle.net/10932/00-0332-C453-CEDC-...
# 40546  http://hdl.handle.net/10932/00-0332-C453-CEDC-...
# 40550  http://www.cs.cmu.edu/~lingwang/microtopia/#weibo
#
#                                                    label persistentId  \
# 379                Bibliography Doing Digital Humanities       qg91Bj
# 396       Bibliography of the History of the Czech Lands       yC3sFv
# 925               CESNET DataCare - Object Based Storage       nCk2Fz
# 926               CESNET DataCare - Object Based Storage       nCk2Fz
# 927               CESNET DataCare - Object Based Storage       nCk2Fz
# ...                                                  ...          ...
# 40514  XV century New Testament translations (Piętnas...       RB8myI
# 40529  York-Helsinki Parsed Corpus of Old English Poetry       gKJuvx
# 40545  Zweite Generation deutschsprachiger Migranten ...       fT0AeP
# 40546  Zweite Generation deutschsprachiger Migranten ...       fT0AeP
# 40550                                             μtopia       ekoDXk
#
#               category
# 379    tool-or-service
# 396    tool-or-service
# 925    tool-or-service
# 926    tool-or-service
# 927    tool-or-service
# ...                ...
# 40514          dataset
# 40529          dataset
# 40545          dataset
# 40546          dataset
# 40550          dataset
#
# [1265 rows x 22 columns]

# %%
df_properties_url["type.code"].unique()
# Out:
# array(['see-also', 'user-manual-url', 'terms-of-use-url',
#        'privacy-policy-url', 'access-policy-url', 'helpdesk-url',
#        'service-level-url'], dtype=object)

# %%
df_all_items.count()
# Out:
# id                                         6050
# category                                   6050
# label                                      6050
# persistentId                               6050
# lastInfoUpdate                             6050
# status                                     6050
# description                                6050
# contributors                               6050
# properties                                 6050
# externalIds                                6050
# accessibleAt                               6050
# sourceItemId                               5874
# relatedItems                               6050
# media                                      6050
# informationContributor.id                  6050
# informationContributor.username            6050
# informationContributor.displayName         6050
# informationContributor.status              6050
# informationContributor.registrationDate    6050
# informationContributor.role                6050
# informationContributor.config              6050
# source.id                                  5874
# source.label                               5874
# source.url                                 5874
# source.urlTemplate                         5874
# version                                      45
# thumbnail.info.mediaId                      118
# thumbnail.info.category                     118
# thumbnail.info.filename                      39
# thumbnail.info.mimeType                     118
# thumbnail.info.hasThumbnail                 118
# thumbnail.info.location.sourceUrl            79
# thumbnail.caption                            67
# dateCreated                                 224
# dateLastUpdated                             403
# composedOf                                   20
# dtype: int64

# %%
urls_df_properties=check.checkURLValuesInDataset(df_all_items.iloc[0:3000], 'terms-of-use-url, user-manual-url, privacy-policy-url, access-policy-url, service-level-url, see-also, helpdesk-url')
urls_df_properties.tail()
# Out:
# inspecting terms-of-use-url
# inspecting user-manual-url
# inspecting privacy-policy-url
# inspecting access-policy-url
# inspecting service-level-url
# inspecting see-also
# inspecting helpdesk-url
#                       MPUrl persistentId         category  \
# 850  tool-or-service/SBcPlO       SBcPlO  tool-or-service
# 851  tool-or-service/BDR3JZ       BDR3JZ  tool-or-service
# 852  tool-or-service/BDR3JZ       BDR3JZ  tool-or-service
# 853  tool-or-service/BDR3JZ       BDR3JZ  tool-or-service
# 854  tool-or-service/BDR3JZ       BDR3JZ  tool-or-service
#
#                                                  label  property  \
# 850                       Virtual Language Observatory  see-also
# 851  Visual Media Service Virtual Research Environment  see-also
# 852  Visual Media Service Virtual Research Environment  see-also
# 853  Visual Media Service Virtual Research Environment  see-also
# 854  Visual Media Service Virtual Research Environment  see-also
#
#                                                 url status
# 850                     https://vlo.clarin.eu/#tour    200
# 851  https://services.d4science.org/web/visualmedia    200
# 852  https://services.d4science.org/web/visualmedia    200
# 853  https://services.d4science.org/web/visualmedia    200
# 854  https://services.d4science.org/web/visualmedia    200

# %%
df_prop_http_status_nf_err=urls_df_properties[urls_df_properties['status'] == 404].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_prop_http_status_serv_err=urls_df_properties[urls_df_properties['status'] == 200].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_prop_http_status_err=pd.concat([df_prop_http_status_nf_err, df_prop_http_status_serv_err])

myclickable_table = df_prop_http_status_err.style.format({'MPUrl': utils.make_clickable})
myclickable_table
# Out:
# <style  type="text/css" >
# </style><table id="T_d217fea0_a94c_11ed_939b_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MPUrl</th>        <th class="col_heading level0 col1" >persistentId</th>        <th class="col_heading level0 col2" >category</th>        <th class="col_heading level0 col3" >label</th>        <th class="col_heading level0 col4" >property</th>        <th class="col_heading level0 col5" >url</th>        <th class="col_heading level0 col6" >status</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row0" class="row_heading level0 row0" >391</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col0" class="data row0 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/8jJUMW">tool-or-service/8jJUMW</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col1" class="data row0 col1" >8jJUMW</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col2" class="data row0 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col3" class="data row0 col3" >DARIAH-DE Data Federation Architecture (DFA)</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col4" class="data row0 col4" >see-also</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col5" class="data row0 col5" >https://de.dariah.eu/en/data-federation-architecture</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row0_col6" class="data row0 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row1" class="row_heading level0 row1" >563</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col0" class="data row1 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/EBuVud">tool-or-service/EBuVud</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col1" class="data row1 col1" >EBuVud</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col2" class="data row1 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col3" class="data row1 col3" >ELDAH Consent Form Wizard</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col4" class="data row1 col4" >see-also</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col5" class="data row1 col5" >https://consent.dariah.eu/startpage</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row1_col6" class="data row1 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row2" class="row_heading level0 row2" >699</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col0" class="data row2 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/aqevCc">tool-or-service/aqevCc</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col1" class="data row2 col1" >aqevCc</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col2" class="data row2 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col3" class="data row2 col3" >Fran- Dictionaries of the Fran Ramovš Institute of the Slovenian Language ZRC SAZU</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col4" class="data row2 col4" >see-also</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col5" class="data row2 col5" >http://www.zrc-sazu.si/en/node</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row2_col6" class="data row2 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row3" class="row_heading level0 row3" >371</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col0" class="data row3 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/yC3sFv">tool-or-service/yC3sFv</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col1" class="data row3 col1" >yC3sFv</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col2" class="data row3 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col3" class="data row3 col3" >Bibliography of the History of the Czech Lands</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col4" class="data row3 col4" >see-also</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col5" class="data row3 col5" >http://www.hiu.cas.cz/cs/</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row3_col6" class="data row3 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row4" class="row_heading level0 row4" >266</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col0" class="data row4 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/1wrJdz">tool-or-service/1wrJdz</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col1" class="data row4 col1" >1wrJdz</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col2" class="data row4 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col3" class="data row4 col3" >Web Panel Sample Service (WPSS)</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col4" class="data row4 col4" >user-manual-url</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col5" class="data row4 col5" >https://cdsp-scpo.github.io/wpss-doc/</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row4_col6" class="data row4 col6" >200</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row5" class="row_heading level0 row5" >729</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col0" class="data row5 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/3DtWVy">tool-or-service/3DtWVy</a></td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col1" class="data row5 col1" >3DtWVy</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col2" class="data row5 col2" >tool-or-service</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col3" class="data row5 col3" >GAMS repository</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col4" class="data row5 col4" >see-also</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col5" class="data row5 col5" >https://zim.uni-graz.at</td>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row5_col6" class="data row5 col6" >200</td>
#             </tr>
#             <tr>
#                         <th id="T_d217fea0_a94c_11ed_939b_acde48001122level0_row6" class="row_heading level0 row6" >562</th>
#                         <td id="T_d217fea0_a94c_11ed_939b_acde48001122row6_col0" class="data row6 col0" ><a target="_blank" href="https://sshoc-marketplace-stage.acdh-dev.oeaw.ac.at/tool-or-service/7j2LI8">tool-or-service/7j2LI8</a></td>
#                         <t

# %% [markdown]
# ### Export of the 404 errors for all URL-based fields

# %%
df_URL_404=pd.concat([df_http_status_nf_err, df_prop_http_status_nf_err])
export_df_URL_404=df_URL_404[['MPUrl', 'label', 'property', 'status', 'url']]
export_df_URL_404.to_csv(path_or_buf='data/brokenURLs.csv', sep=',', index=False)

# %% [markdown]
# ### Flag items with wrong URLs in the Dataset

# %%
df_URL_flags=pd.concat([df_http_status_err, urls_df_properties])

# %%
curation_flag_property={"code": "curation-flag-url"}
curation_detail_property={"code": "curation-detail"}

# %%
res=mpdata.setHTTPStatusFlags(df_URL_flags, curation_flag_property, curation_detail_property)
# Out:
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '1710.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/yC3sFv has a *404* HTTP status for the property see-also, (False)
# Appending curation_detail_flag {'url': [ {"see-also": "404"}]}
#
#
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# The item with PID: tools/FOhmdk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/I2egYT has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/i3v5q0 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/Ntf7jP has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/JlGcvp has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '1806.0'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/GwWY2h has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/G4iyld has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '3757.0'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/oVSGJ5 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/mrFG7W has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/HLnGEm has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '1796.0'}}
# dv {'description': {'length': '1796.0'}}
# dv {'description': {'length': '1796.0'}}
# dv {'description': {'length': '1796.0'}}
# dv {'description': {'length': '1796.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/WCXCgY has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'actor.website': '404'},  {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '2633.0'}}
# The item with PID: tools/8jJUMW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/8jJUMW has a *404* HTTP status for the property see-also, (False)
# Appending curation_detail_flag  {'url': [ {'see-also': '404'},  {"accessibleAt": "404"}]}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '1664.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': '2294.0'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/OKoqgh has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {"url": [{"accessibleAt": "404"}], "description": "{\"length\": \"2855.0\"}"}
#
# The item with PID: tools/gfF0V9 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'url': [{'actor.website': '404'}]}
# dv {'url': [{'actor.website': '404'}]}
# The item with PID: tools/V6aWAu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'actor.website': '404'},  {"accessibleAt": "404"}]}
#
# The item with PID: tools/2YMYaD has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/tjoXDf has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/EBuVud has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/EBuVud has a *404* HTTP status for the property see-also, (False)
# Appending curation_detail_flag  {'url': [ {'see-also': '404'},  {"accessibleAt": "404"}]}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# The item with PID: tools/C80AK6 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '1663.0'}}
# The item with PID: tools/3ZpHvD has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/F4hxi5 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/thoAhw has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/CzSzkq has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/aqevCc has a *404* HTTP status for the property see-also, (False)
# Appending curation_detail_flag {'url': [ {"see-also": "404"}]}
#
#
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/S2Bt9F has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/KNVuNk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '2673.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '2973.0'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/aY4ryv has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "nan"}}
#
# The item with PID: tools/AReBKR has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/EcLbxP has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': '1671.0'}}
# dv {'description': {'length': '1671.0'}}
# dv {'description': {'length': '1671.0'}}
# dv {'description': {'length': '1671.0'}}
# dv {'description': {'length': '1671.0'}}
# dv {'description': {'length': '1671.0'}}
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/qPAlNr has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/cNoDXu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/grnqNn has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/vi3pn2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/Y6plQG has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/ShyS5V has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/txkgP4 has a *503* HTTP status for the property see-also, (False)
# Appending curation_detail_flag  {'url': [ {'see-also': '503'},  {"accessibleAt": "503"}]}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# The item with PID: tools/7KpXCE has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/phKCUD has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# dv {'description': {'length': 'nan'}}
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/aQK2rq has a *503* HTTP status for the property terms-of-use-url, (False)
# Appending curation_detail_flag  {'url': [ {'terms-of-use-url': '503'},  {"accessibleAt": "503"}]}
# dv {'url': [{'terms-of-use-url': '503'}, {'accessibleAt': '503'}]}
# Dropping flag {'accessibleAt': '503'} ...
# done.
# Dropping flag {'terms-of-use-url': '503'} ...
# done.
# The item with PID: tools/aQK2rq has a *no longer valid flag* for the property user-manual-url, will be removed. (True)
# The item with PID: tools/aQK2rq has a *503* HTTP status for the property privacy-policy-url, (True)
# Appending curation_detail_flag  {'url': [ {'privacy-policy-url': '503'}], "url": []}
# The item with PID: tools/aQK2rq has a *503* HTTP status for the property access-policy-url, (True)
# Appending curation_detail_flag  {'url': [ {'access-policy-url': '503'},  {'privacy-policy-url': '503'}], "url": []}
# dv {'url': []}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': 'nan'}}
# dv {'relations': {'length': '1'}}
# dv {'relations': {'length': '1'}}
# The item with PID: tools/veS7n4 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "nan"}}
#
# The item with PID: tools/Vus9vX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '1705.0'}}
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': 'nan'}}
# dv {'url': [{'actor.website': '404'}]}
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': '3980.0'}}
# dv {'description': {'length': '3980.0'}}
# dv {'description': {'length': '3980.0'}}
# dv {'description': {'length': '1778.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '1602.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '1548.0'}}
# dv {'url': [{'actor.website': '404'}]}
# The item with PID: tools/pxZXbd has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'url': [{'actor.website': '404'}]}
# The item with PID: tools/UdB9FI has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '4003.0'}}
# The item with PID: tools/X2UbFI has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/Ywh9Fb has a *503* HTTP status for the property see-also, (False)
# Appending curation_detail_flag {'url': [ {"see-also": "503"}]}
#
#
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# The item with PID: tools/6xmMnK has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/1vuuAw has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/VJM4IO has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/o0tPZv has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/7Qmlo4 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/UlRiAy has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '2033.0'}}
# The item with PID: tools/pCrueW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '4063.0'}}
# dv {'description': {'length': '4063.0'}}
# dv {'description': {'length': '4063.0'}}
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/t4Tzag has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/bvr6CG has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/knCfk3 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'url': [{'actor.website': '404'}]}
# dv {'description': {'length': '2985.0'}}
# dv {'relations': {'length': '1'}}
# The item with PID: tools/uMJTY6 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/8ZKBhu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'url': [{'actor.website': '404'}]}
# dv {'url': [{'actor.website': '404'}]}
# The item with PID: tools/DyMdd6 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'accessibleAt': '404'},  {"actor.website": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/6ArGjA has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': 'nan'}}
# The item with PID: tools/25grr1 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/mfmPPR has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: tools/kRIrWC has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '1667.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/PHIvDM has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "23.0"}}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/kH3aeT has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "23.0"}}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '1522.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/N4FzDi has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "23.0"}}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/JhHnqB has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "23.0"}}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/CddrcN has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag  {'url': [ {'accessibleAt': '404'}], "description": {'url': [ {'accessibleAt': '404'}], "length": "23.0"}}
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# The item with PID: publications/I0TnYt has a *404* HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# *** Running in DEBUG mode, Marketplace dataset not updated. ***
#
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '2995.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': 'nan'}}
# dv {'description': {'length': '23.0'}}
# dv {'description': {'length': '23.0'}}
# ...
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/v48WBl has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# The item with PID: datasets/3W5E6J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Zrq9lF has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/x2xkU7 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/D4WBU2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Qe5gex has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tKZRRu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/oTBwOX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pRSAhb has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/JkfwMn has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VlzZY8 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/NAqO5J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/o2E85y has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/b7JHCS has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/TTchK9 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/44i9Jt has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/CsNthk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VZgKHW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pIkR6V has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/GrPnlA has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/xYzyWX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tSHqO2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/jQvQhg has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/v48WBl has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/3W5E6J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Zrq9lF has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/x2xkU7 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/D4WBU2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Qe5gex has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tKZRRu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/oTBwOX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pRSAhb has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/JkfwMn has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VlzZY8 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/NAqO5J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/o2E85y has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/b7JHCS has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/TTchK9 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/44i9Jt has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/CsNthk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VZgKHW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pIkR6V has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/GrPnlA has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/xYzyWX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tSHqO2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/jQvQhg has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/v48WBl has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/3W5E6J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Zrq9lF has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/x2xkU7 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/D4WBU2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Qe5gex has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tKZRRu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# The item with PID: datasets/oTBwOX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pRSAhb has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/JkfwMn has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VlzZY8 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/NAqO5J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/o2E85y has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/b7JHCS has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/TTchK9 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/44i9Jt has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/CsNthk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VZgKHW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pIkR6V has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/GrPnlA has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/xYzyWX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tSHqO2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/jQvQhg has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/v48WBl has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/3W5E6J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Zrq9lF has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/x2xkU7 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/D4WBU2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Qe5gex has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tKZRRu has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/oTBwOX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pRSAhb has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/JkfwMn has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VlzZY8 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/NAqO5J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/o2E85y has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/b7JHCS has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/TTchK9 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/44i9Jt has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/CsNthk has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/VZgKHW has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/pIkR6V has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/GrPnlA has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/xYzyWX has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/tSHqO2 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/jQvQhg has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/v48WBl has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/3W5E6J has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/Zrq9lF has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
#
# The item with PID: datasets/x2xkU7 has a *404* HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}

# %% [markdown]
# #### Variant: check error values in URL-based properties for items from a specific source

# %% [markdown]
# Create a dataframe with all the items having the EOSC Catalogue source

# %%
df_ec_items=df_all_items[df_all_items['source.label']=='EOSC Catalogue']

# %%
df_ec_items.head(3)

# %% [markdown]
# Check the URL properties by invoking the function **checkURLValuesInDataset(dataset, props)**

# %%
urls_df_hd=check.checkURLValuesInDataset(df_ec_items, 'terms-of-use-url, user-manual-url, privacy-policy-url, access-policy-url, service-level-url, see-also, helpdesk-url')
urls_df_hd.head()

# %%
urls_df_hd_status_nf_err=urls_df_hd[urls_df_hd['status'] == 404].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)

# %%
myclickable_table = urls_df_hd_status_nf_err.style.format({'MPUrl': utils.make_clickable})
myclickable_table
