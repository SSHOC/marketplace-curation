# %% [markdown]
# # Notebook 3.1 - Curation-flag-URL
#
# This notebook analyses the URL-based fields of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-url` and `curation-detail` properties.
#
# This notebook flags Marketplace items that have errors in their URL-based fields, helping Moderators identify curation priorities to improve data quality.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 4 sections:
#
# 0. Requirements to run the notebook
# 1. Check & flag error values in `accessibleAt`
# 2. Check & flag error values in URL-based properties
# 3. Check & flag error values in URL-based properties for a given source - example

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data
#
# df_all_items.head() will show the first 5 rows of the dataframe
#
# df_all_items.tail() will show the 5 last rows of the dataframe
#
# df_all_items.shape will give the dataframe shape (number of rows and columns)

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  28230  tool-or-service                                             140kit
# 1  36324  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  36552  tool-or-service                                              3DHOP
# 3  36555  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  36189  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       SIU1nO  2021-11-23T17:24:25+0000  approved
# 1       4gDAHv  2022-01-13T11:49:02+0000  approved
# 2       UcxOmD  2022-01-13T11:50:31+0000  approved
# 3       uFIMPQ  2022-01-13T11:50:32+0000  approved
# 4       kAkzuz  2022-01-13T11:47:44+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1  3DF Zephyr\[1\]\[2\] is a commercial photogram...
# 2  3DHOP (3D Heritage Online Presenter) is an ope...
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 2224, 'name': 'Ian Pearce, D...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'mode-of-use', 'label': 'Mo...          []  ...
# 1  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 2  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 3                                                 []          []  ...
# 4  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
#
#   thumbnail.info.mediaId thumbnail.info.category thumbnail.info.filename  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#   thumbnail.info.mimeType  thumbnail.info.hasThumbnail  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#   thumbnail.info.location.sourceUrl thumbnail.caption dateCreated  \
# 0                               NaN               NaN         NaN
# 1                               NaN               NaN         NaN
# 2                               NaN               NaN         NaN
# 3                               NaN               NaN         NaN
# 4                               NaN               NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# `df_all_items_work` selects the columns/attributes of interest

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 303  12634       l8gLBb  dataset
# 304  12631       xvYQQ4  dataset
# 305  12632       IdZGtV  dataset
# 306  12633       OMny6U  dataset
# 307  12589       YnEaU0  dataset
#
#                                                  label  \
# 303                    Yelp Academic Challenge Dataset
# 304                                            YelpCHI
# 305                                            YelpNYC
# 306                                            YelpZIP
# 307  "You Are Where You Tweet: A Content-Based Appr...
#
#                                           contributors  \
# 303  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 304  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 303                    [https://www.yelp.com/dataset]  Humanities Data
# 304  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 305  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 307   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check & flag values in `accessibleAt`
#
# `accessibleAt` is the main URL field of MP items.
#
# The following cell checks if there are empty values in `accessibleAt` for all items

# %%
df_all_items_work_emptyurls=df_all_items_work[df_all_items_work['accessibleAt'].str.len()==0]

emptyurldescriptionsn=df_all_items_work_emptyurls.count()[0]

print(f'\n There are {emptyurldescriptionsn} items without accessibleAt URLs\n')
# Out:
#  There are 526 items without accessibleAt URLs

# %% [markdown]
# ### 1.1 Check the validity of URLs in the accessibleAt property using the HTTP Result Status code
#
# The code below explicitly execute an http call for every URL, waits for the [Result Status Code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) of the call and then registers the code.
# Depending on connections and server answer times it may take several minutes to process all URLs.

# %%
#The list of categories is defined in the following statement

categories="toolsandservices"#, publications, trainingmaterials, workflows, datasets"

check=eva.URLCheck()
df_urls=check.checkURLValues(categories, 'accessibleAt')
df_urls.head()
# Out:
# inspecting accessibleAt
#                     MPUrl persistentId         category  \
# 0  tool-or-service/SIU1nO       SIU1nO  tool-or-service
# 1  tool-or-service/4gDAHv       4gDAHv  tool-or-service
# 2  tool-or-service/UcxOmD       UcxOmD  tool-or-service
# 3  tool-or-service/uFIMPQ       uFIMPQ  tool-or-service
# 4  tool-or-service/kAkzuz       kAkzuz  tool-or-service
#
#                                                label      property  \
# 0                                             140kit  accessibleAt
# 1  3DF Zephyr - photogrammetry software - 3d mode...  accessibleAt
# 2                                              3DHOP  accessibleAt
# 3                3DHOP: 3D Heritage Online Presenter  accessibleAt
# 4                           3DReshaper \| 3DReshaper  accessibleAt
#
#                                                  url status
# 0        https://github.com/WebEcologyProject/140kit    200
# 1  https://www.3dflow.net/3df-zephyr-pro-3d-model...    200
# 2                      http://vcg.isti.cnr.it/3dhop/    200
# 3            https://github.com/cnr-isti-vclab/3DHOP    200
# 4                     https://www.3dreshaper.com/en/    200

# %%
df_urls.shape
# Out:
# (1878, 7)

# %%
df_urls.drop_duplicates(keep='first', inplace=True)

# %%
df_urls.shape
# Out:
# (1220, 7)

# %%
utils=hel.Util()
df_http_status_nf_err=df_urls[df_urls['status'] == 404].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_http_status_serv_err=df_urls[df_urls['status'] == 200].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
df_http_status_err=pd.concat([df_http_status_nf_err, df_http_status_serv_err])
df_http_status_err=df_urls.sort_values('persistentId').drop_duplicates(keep='first', inplace=False)
#df_http_status_err.to_pickle('data/urlstatus.pickle')
#df_http_status_nf_err.to_pickle('data/urlstatus404.pickle')
myclickable_table = df_http_status_nf_err.style.format({'MPUrl': utils.make_clickable})
myclickable_table
# Out:
# <style  type="text/css" >
# </style><table id="T_3168acec_8419_11ec_8c9a_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MPUrl</th>        <th class="col_heading level0 col1" >persistentId</th>        <th class="col_heading level0 col2" >category</th>        <th class="col_heading level0 col3" >label</th>        <th class="col_heading level0 col4" >property</th>        <th class="col_heading level0 col5" >url</th>        <th class="col_heading level0 col6" >status</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row0" class="row_heading level0 row0" >1380</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col0" class="data row0 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/25grr1">tool-or-service/25grr1</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col1" class="data row0 col1" >25grr1</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col2" class="data row0 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col3" class="data row0 col3" >VLE - Viennese Lexicographic Editor</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col4" class="data row0 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col5" class="data row0 col5" >https://www.oeaw.ac.at/en/acdh/tools/vle/</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row0_col6" class="data row0 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row1" class="row_heading level0 row1" >375</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col0" class="data row1 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/3ZpHvD">tool-or-service/3ZpHvD</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col1" class="data row1 col1" >3ZpHvD</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col2" class="data row1 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col3" class="data row1 col3" >Finding People or Characters from A Text (Named-Entity Recognition)</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col4" class="data row1 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col5" class="data row1 col5" >https://github.com/TAPoR-3-Tools/Tapor-Coding-Tools/tree/master/tapor_coding_tools/natural%20language%20processing/Finging%20people%20or%20characters%20with%20NER</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row1_col6" class="data row1 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row2" class="row_heading level0 row2" >1217</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col0" class="data row2 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/6xmMnK">tool-or-service/6xmMnK</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col1" class="data row2 col1" >6xmMnK</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col2" class="data row2 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col3" class="data row2 col3" >Tagger - Other (TAPoRware)</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col4" class="data row2 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col5" class="data row2 col5" >http://taporware.ualberta.ca/~taporware/otherTools/tagger.shtml</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row2_col6" class="data row2 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row3" class="row_heading level0 row3" >1843</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col0" class="data row3 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/Aezoqo">tool-or-service/Aezoqo</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col1" class="data row3 col1" >Aezoqo</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col2" class="data row3 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col3" class="data row3 col3" >Wordle</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col4" class="data row3 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col5" class="data row3 col5" >http://www.wordle.net/</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row3_col6" class="data row3 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row4" class="row_heading level0 row4" >363</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col0" class="data row4 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/C80AK6">tool-or-service/C80AK6</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col1" class="data row4 col1" >C80AK6</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col2" class="data row4 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col3" class="data row4 col3" >Extract Text From HTML - Beta (TAPoRware)</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col4" class="data row4 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col5" class="data row4 col5" >http://taporware.ualberta.ca/~taporware/betaTools/textextractor.shtml</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row4_col6" class="data row4 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row5" class="row_heading level0 row5" >379</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col0" class="data row5 col0" ><a target="_blank" href="https://marketplace-api.sshopencloud.eu/tool-or-service/CzSzkq">tool-or-service/CzSzkq</a></td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col1" class="data row5 col1" >CzSzkq</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col2" class="data row5 col2" >tool-or-service</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col3" class="data row5 col3" >Fixed Phrase - XML (TAPoRware)</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col4" class="data row5 col4" >accessibleAt</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col5" class="data row5 col5" >http://taporware.ualberta.ca/~taporware/xmlTools/fixedphrase-xml.shtml</td>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row5_col6" class="data row5 col6" >404</td>
#             </tr>
#             <tr>
#                         <th id="T_3168acec_8419_11ec_8c9a_acde48001122level0_row6" class="row_heading level0 row6" >725</th>
#                         <td id="T_3168acec_8419_11ec_8c9a_acde48001122row6_col0" class="data row6 col0" ><a target="_blank" href=

# %%
df_http_status_nf_err.shape
# Out:
# (39, 7)

# %% [markdown]
# ### 1.2 Flag items with wrong accessibleAt URLs in the Dataset

# %%
curation_flag_property={"code": "curation-flag-url"}
curation_detail_property={"code": "curation-detail"}

# %%
res=mpdata.setHTTPStatusFlags(df_http_status_nf_err, curation_flag_property, curation_detail_property)
# Out:
# accessibleAt, tools
#
# The item with PID: FOhmdk has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: I2egYT has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: i3v5q0 has a 404 HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# Running in debug mode, Marketplace dataset not updated.
# accessibleAt, tools
#
# The item with PID: GwWY2h has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: G4iyld has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: oVSGJ5 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: mrFG7W has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: HLnGEm has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: WCXCgY has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'actor.website': '404'},  {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: OKoqgh has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: gfF0V9 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: V6aWAu has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {'actor.website': '404'},  {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: ak3Xvt has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: tjoXDf has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: C80AK6 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: 3ZpHvD has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: F4hxi5 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: thoAhw has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: CzSzkq has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: S2Bt9F has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: KNVuNk has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: aY4ryv has a 404 HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# Running in debug mode, Marketplace dataset not updated.
# accessibleAt, tools
#
# The item with PID: EcLbxP has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: vi3pn2 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: Y6plQG has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: veS7n4 has a 404 HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# Running in debug mode, Marketplace dataset not updated.
# accessibleAt, tools
#
# The item with PID: Vus9vX has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: zwJRaY has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: UdB9FI has a 404 HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# Running in debug mode, Marketplace dataset not updated.
# accessibleAt, tools
#
# The item with PID: X2UbFI has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: 6xmMnK has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: UlRiAy has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: t4Tzag has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: bvr6CG has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: knCfk3 has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: 25grr1 has a 404 HTTP status for the property accessibleAt, (False)
# Appending curation_detail_flag {'url': [ {"accessibleAt": "404"}]}
#
#
#
# Running in debug mode, Marketplace dataset not updated.
# accessibleAt, tools
#
# The item with PID: mfmPPR has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: kRIrWC has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}
# accessibleAt, tools
#
# The item with PID: Aezoqo has a 404 HTTP status for the property accessibleAt, (False)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}]}

# %% [markdown]
# ## 2. Check & flag error values in URL-based properties

# %%
df_properties=utils.getProperties()
df_properties.head()

# %%
df_properties["type.type"].unique()

# %%
df_properties_url=df_properties[df_properties["type.type"]=="url"]
df_properties_url

# %%
df_properties_url["type.code"].unique()

# %%
urls_df_properties=check.checkURLValuesInDataset(df_all_items, 'terms-of-use-url, user-manual-url, privacy-policy-url, access-policy-url, service-level-url, see-also, helpdesk-url')
urls_df_properties.tail()

# %% [markdown]
# ### Check error values in URL-based properties for items whose source is: *EOSC Catalogue*

# %% [markdown]
# Create a dataframe with all the items having the EOSC Catalogue source

# %%
df_ec_items=df_all_items[df_all_items['source.label']=='EOSC Catalogue']

# %%
df_ec_items.head(3)

# %% [markdown]
# Check the URL properties by invoking the function **checkURLValuesInDataset(dataset, props)**

# %%
urls_df_hd=check.checkURLValuesInDataset(df_ec_items, 'terms-of-use-url, user-manual-url, privacy-policy-url, access-policy-url, service-level-url, see-also, helpdesk-url')
urls_df_hd.head()

# %%
urls_df_hd_status_nf_err=urls_df_hd[urls_df_hd['status'] == 404].sort_values('persistentId').drop_duplicates(keep='first', inplace=False)

# %%
myclickable_table = urls_df_hd_status_nf_err.style.format({'MPUrl': utils.make_clickable})
myclickable_table
