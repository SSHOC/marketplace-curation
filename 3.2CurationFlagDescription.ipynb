# %% [markdown]
# # Notebook 3.2 - Curation-flag-description
#
# This notebook analyses the `description` fields of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-description` and `curation-detail` properties.
#
# This notebook flags Marketplace items that have empty, too short or too long descriptions, helping Moderators identify curation priorities to improve data quality.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 3 sections:
#
# 0. Requirements to run the notebook
# 1. Check the length of the text stored in the `description` field
# 2. Flag items with empty/short/long `description` in the Dataset

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  45953  tool-or-service                                             140kit
# 1  49576  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  49577  tool-or-service                                              3DHOP
# 3  49578  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  49579  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       3IAyEp  2021-07-30T16:03:01+0000  approved
# 1       U3gQrh  2021-09-22T15:51:38+0000  approved
# 2       MnpOWX  2021-09-22T15:51:39+0000  approved
# 3       gA7zFN  2021-09-22T15:51:39+0000  approved
# 4       Q49CiV  2021-09-22T15:51:40+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1                           No description provided.
# 2                           No description provided.
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 483, 'name': 'Ian Pearce, De...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'activity', 'label': 'Activ...          []  ...
# 1  [{'type': {'code': 'curation-flag-description'...          []  ...
# 2  [{'type': {'code': 'curation-flag-description'...          []  ...
# 3  [{'type': {'code': 'curation-flag-description'...          []  ...
# 4  [{'type': {'code': 'curation-flag-description'...          []  ...
#
#   thumbnail.info.filename thumbnail.info.mimeType thumbnail.info.hasThumbnail  \
# 0      acdh-ch-logo96.png               image/png                        True
# 1                     NaN                     NaN                         NaN
# 2                     NaN                     NaN                         NaN
# 3                     NaN                     NaN                         NaN
# 4                     NaN                     NaN                         NaN
#
#                         thumbnail.caption  version  \
# 0  test thumbnail of uploaded media image      NaN
# 1                                     NaN      NaN
# 2                                     NaN      NaN
# 3                                     NaN      NaN
# 4                                     NaN      NaN
#
#   thumbnail.info.location.sourceUrl informationContributor.email dateCreated  \
# 0                               NaN                          NaN         NaN
# 1                               NaN                          NaN         NaN
# 2                               NaN                          NaN         NaN
# 3                               NaN                          NaN         NaN
# 4                               NaN                          NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 37 columns]

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'description', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 303  12634       l8gLBb  dataset
# 304  12631       xvYQQ4  dataset
# 305  12632       IdZGtV  dataset
# 306  12633       OMny6U  dataset
# 307  12589       YnEaU0  dataset
#
#                                                  label  \
# 303                    Yelp Academic Challenge Dataset
# 304                                            YelpCHI
# 305                                            YelpNYC
# 306                                            YelpZIP
# 307  "You Are Where You Tweet: A Content-Based Appr...
#
#                                            description  \
# 303  The Yelp dataset is a subset of our businesses...
# 304  This dataset is collected from Yelp.com and fi...
# 305  This dataset is collected from Yelp.com and fi...
# 306  This dataset is collected from Yelp.com and fi...
# 307  This dataset is a collection of scraped public...
#
#                                           contributors  \
# 303  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 304  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 303                    [https://www.yelp.com/dataset]  Humanities Data
# 304  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 305  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 307   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check the length of the text stored in the `description` field
#
# By default, and according to rules set up in the Editorial Guidelines [add link], the minimum number of characters is set up to 25 and the maximum to 1500, but these parameters can be modified in the cell below.
#
# An overview of the items description length is also given in notebook *2.SSH Open Marketplace data quality overview*

# %%
minchars=25
maxchars=1500

utils=hel.Util()

df_items = df_tool_flat.replace(utils.empty_description, np.nan)

df_items_d = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()>=minchars) & (df_items['description'].str.len()<=maxchars)]

df_items_min = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()<minchars)]

df_items_max = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()>maxchars)]

print (f"\nThere are {df_items['description'].isna().sum()} items with empty descriptions, "+
       f" {df_items_min['description'].count()} items with description shorter than {minchars} characters,"+
f" {df_items_max['description'].count()} Items with description longer than {maxchars} characters, "+
      f" {df_items_d['description'].count()} Items with description between {minchars} and {maxchars} characters.")
# Out:
# There are 166 items with empty descriptions,  35 items with description shorter than 25 characters, 27 Items with description longer than 1500 characters,  1638 Items with description between 25 and 1500 characters.

# %%
df_items_null = df_items[(df_items['description'].isnull())]

# %%
nv_description_df=pd.concat([df_items_min, df_items_max, df_items_null])
tempdf=nv_description_df[['persistentId', 'label', 'description']]
tempdf['property']='description'
tempdf['value']=tempdf['description'].str.len()
# Out:
# /var/folders/x6/4rl3xlp91ll551m6vbkh32xm0000gn/T/ipykernel_42806/1132137795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['property']='description'
# /var/folders/x6/4rl3xlp91ll551m6vbkh32xm0000gn/T/ipykernel_42806/1132137795.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['value']=tempdf['description'].str.len()

# %%
tempdf.to_pickle('data/descrlength.pickle')

# %%
tempdf.head()
# Out:
#     persistentId                label              description     property  \
# 91        zsKANt  areMediaEqual crash      areMediaEqual crash  description
# 174       ef1r3I               Bread!                   Bread!  description
# 208       MWcv85              Chartle  Create simple charts.\n  description
# 297       xMeq9F            cool tool     very very cool tool!  description
# 771       31D6PR                KSHIP                     TEST  description
#
#      value
# 91    19.0
# 174    6.0
# 208   22.0
# 297   20.0
# 771    4.0

# %% [markdown]
# ## 2. Flag items with empty/short/long `description` in the Dataset

# %%
curation_flag_property={"code": "curation-flag-description"}
curation_detail_property={"code": "curation-detail"}

# %%
# categories="toolsandservices";"publications";"trainingmaterials";"workflows";"datasets"
# res=mpdata.setPropertyStatusFlags(tempdf, categories, curation_flag_property, curation_detail_property)
res_des=mpdata.setPropertyFlags(tempdf, curation_flag_property, curation_detail_property)
# Out:
# Creating log file...
# The property: description, has value nan, in item with pid: tools/U3gQrh, (current version: 49576)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/MnpOWX, (current version: 49577)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/gA7zFN, (current version: 49578)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Q49CiV, (current version: 49579)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/sZbdSF, (current version: 49580)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/wIhZrL, (current version: 49581)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/rfqwD3, (current version: 63406)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6mbfxV, (current version: 49583)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/JtvFFr, (current version: 49584)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6jsUiF, (current version: 49585)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/07LcFY, (current version: 49586)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/iJHK6Q, (current version: 49587)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/cy1Z2L, (current version: 49588)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/MsWHEO, (current version: 49589)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 19.0, in item with pid: tools/zsKANt, (current version: 63969)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "19.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 3256.0, in item with pid: tools/RkWcCH, (current version: 49590)
# flag property exists, value:  {'description':  {"length": "3256"}}
# The property: description, has value 1839.0, in item with pid: tools/2qcJ9k, (current version: 49591)
# flag property exists, value:  {'description':  {"length": "1839"}}
# The property: description, has value nan, in item with pid: tools/qrVeJj, (current version: 49592)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6cUr3I, (current version: 49593)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1710.0, in item with pid: tools/x4yxxi, (current version: 49594)
# flag property exists, value:  {'description':  {"length": "1710"}}
# The property: description, has value nan, in item with pid: tools/Uudy7B, (current version: 49595)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/mToGiG, (current version: 49596)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/m5GUi8, (current version: 49597)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ZXKkPc, (current version: 49598)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/LBrfwN, (current version: 49599)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/hgJ2n8, (current version: 49600)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 6.0, in item with pid: tools/ef1r3I, (current version: 64103)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "6.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: tools/szesTz, (current version: 49601)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/zW1PT4, (current version: 49602)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/uXb4I4, (current version: 49603)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/3gNpSp, (current version: 49604)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}], 'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/qTeolj, (current version: 49605)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 22.0, in item with pid: tools/MWcv85, (current version: 49606)
# flag property exists, value:  {'description':  {"length": "22"}}
# The property: description, has value 1806.0, in item with pid: tools/LCWpDD, (current version: 49607)
# flag property exists, value:  {'description':  {"length": "1806"}}
# The property: description, has value nan, in item with pid: tools/dKMvYR, (current version: 49608)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/oM2qv9, (current version: 49609)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ukgMGu, (current version: 57035)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1815.0, in item with pid: tools/tvFcl6, (current version: 49611)
# flag property exists, value:  {'description':  {"length": "1815"}}
# The property: description, has value nan, in item with pid: tools/46A8Mp, (current version: 49612)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/XXxx1Q, (current version: 49614)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/GBqKKp, (current version: 49613)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/lYOTzL, (current version: 49615)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ArlMj5, (current version: 49616)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 20.0, in item with pid: tools/xMeq9F, (current version: 49617)
# flag property exists, value:  {'description':  {"length": "20"}}
# The property: description, has value nan, in item with pid: tools/JgQrly, (current version: 49618)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/O4TFOF, (current version: 49619)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/m6UcHW, (current version: 49620)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/IJAZPX, (current version: 49621)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Oo3zrP, (current version: 49622)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/BYpzDJ, (current version: 49623)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 2315.0, in item with pid: tools/EaoFwn, (current version: 49624)
# flag property exists, value:  {'description':  {"length": "2315"}}
# The property: description, has value nan, in item with pid: tools/ChTZF1, (current version: 49625)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/2IOMAi, (current version: 49626)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 2855.0, in item with pid: tools/ip7fwu, (current version: 56980)
# flag property exists, value:  {'description':  {"length": "2855"}}
# The property: description, has value nan, in item with pid: tools/aTIg31, (current version: 49628)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/N3wDml, (current version: 49629)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/j3FSl8, (current version: 49630)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/WbcPgL, (current version: 49631)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/JNeZjf, (current version: 49632)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/GHlkFz, (current version: 49633)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1829.0, in item with pid: tools/5QwvKB, (current version: 49636)
# flag property exists, value:  {'url': [ {"accessibleAt": "503"}], 'description':  {"length": "1829"}}
# The property: description, has value 1829.0, in item with pid: tools/Lut8V2, (current version: 49635)
# flag property exists, value:  {'url': [ {"accessibleAt": "503"}], 'description':  {"length": "1829"}}
# The property: description, has value 1829.0, in item with pid: tools/sYZNY8, (current version: 49634)
# flag property exists, value:  {'url': [ {"accessibleAt": "503"}], 'description':  {"length": "1829"}}
# The property: description, has value nan, in item with pid: tools/ARCTca, (current version: 49637)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/o2Fe3l, (current version: 49638)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/smgx6S, (current version: 49639)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1663.0, in item with pid: tools/FuhNgx, (current version: 49645)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value 1663.0, in item with pid: tools/7QZeNR, (current version: 49644)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value 1663.0, in item with pid: tools/8lZhlS, (current version: 49643)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value 1663.0, in item with pid: tools/1s5kkT, (current version: 49642)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value 1663.0, in item with pid: tools/5PsJga, (current version: 49641)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value 1663.0, in item with pid: tools/QzcLJ6, (current version: 49640)
# flag property exists, value:  {'description':  {"length": "1663"}}
# The property: description, has value nan, in item with pid: tools/e05E3e, (current version: 49646)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/48H2xs, (current version: 49647)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/LWRqHf, (current version: 62702)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/qfWaSc, (current version: 49649)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/46xJuM, (current version: 49650)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/359eAS, (current version: 49651)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 2673.0, in item with pid: tools/KD7bWX, (current version: 49652)
# flag property exists, value:  {'description':  {"length": "2673"}}
# The property: description, has value nan, in item with pid: tools/wPtjJQ, (current version: 49653)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/H0Q2rz, (current version: 49654)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/kXov9q, (current version: 49655)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Ap2X5K, (current version: 49656)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/sjXmim, (current version: 49657)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 2973.0, in item with pid: tools/VcKW9f, (current version: 49658)
# flag property exists, value:  {'description':  {"length": "2973"}}
# The property: description, has value nan, in item with pid: tools/uGBy4a, (current version: 49659)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/1qi8LE, (current version: 49660)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/aIsaE0, (current version: 49662)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/V7UEeD, (current version: 49663)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}], 'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/MLgZHk, (current version: 49664)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/YqA2cM, (current version: 49665)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/pSpOYE, (current version: 49666)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/s40Fax, (current version: 49667)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/RNEXKy, (current version: 49668)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Vt0iGX, (current version: 49669)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/pCyD7m, (current version: 49670)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/1IIzLN, (current version: 49671)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/WVuCDO, (current version: 49672)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 4.0, in item with pid: tools/31D6PR, (current version: 61392)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/eLkZQr, (current version: 57105)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/BNsziZ, (current version: 57104)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/JDUkiK, (current version: 57103)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/MStKce, (current version: 57102)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/hevVE1, (current version: 55689)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "4.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4.0, in item with pid: tools/BDAYZ4, (current version: 55687)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "4.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4.0, in item with pid: tools/nGNUcR, (current version: 55684)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "4.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4.0, in item with pid: tools/2FyWax, (current version: 49677)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/jfwo7e, (current version: 49676)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/YgTuvV, (current version: 49674)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/l1VVrw, (current version: 49673)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value nan, in item with pid: tools/F5bCCX, (current version: 49682)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/WfhTvQ, (current version: 49683)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ZDvz7x, (current version: 49684)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/IM1dfz, (current version: 49685)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/VvOxec, (current version: 49686)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/HM0p1K, (current version: 49687)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/jrsnaO, (current version: 49688)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/WYAbgp, (current version: 49689)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6pzH8R, (current version: 49690)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/TWTfbO, (current version: 49691)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/NNRC1j, (current version: 49692)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/o7W8q4, (current version: 49693)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/QuGQNy, (current version: 49694)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/xcMz6G, (current version: 49695)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/9VCTZL, (current version: 49697)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/5yweb6, (current version: 49696)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/qsYqHk, (current version: 49698)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/BeyaDM, (current version: 49699)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/02Iax3, (current version: 49700)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Bt7BX4, (current version: 49701)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ZFJ7ZR, (current version: 49702)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/FAKltF, (current version: 49703)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/fFCAmf, (current version: 49704)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/inTLV2, (current version: 49705)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/f9MLfm, (current version: 49706)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/LLfGly, (current version: 49707)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/EipkQb, (current version: 49708)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Kawnkr, (current version: 57880)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/aXRnTG, (current version: 49710)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1705.0, in item with pid: tools/kF4ba6, (current version: 49711)
# flag property exists, value:  {'description':  {"length": "1705"}}
# The property: description, has value nan, in item with pid: tools/E0gqiN, (current version: 49712)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/dfV3ji, (current version: 49713)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/8z8FjZ, (current version: 49714)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6e7dcT, (current version: 49715)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/FHqtcW, (current version: 49716)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/uU7WUP, (current version: 49717)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/IV2Rgd, (current version: 49718)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 3980.0, in item with pid: tools/gFfPQl, (current version: 63835)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "3980.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1778.0, in item with pid: tools/AuElGh, (current version: 49719)
# flag property exists, value:  {'description':  {"length": "1778"}}
# The property: description, has value nan, in item with pid: tools/DLZHbH, (current version: 49720)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/UbL5ok, (current version: 49721)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/8rTzjv, (current version: 49722)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/srPMJU, (current version: 49723)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/S75qHH, (current version: 49724)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/n2LvQz, (current version: 49725)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/JJFBdM, (current version: 49726)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/QO3kr7, (current version: 49727)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1548.0, in item with pid: tools/Eh9YGe, (current version: 49728)
# flag property exists, value:  {'description':  {"length": "1548"}}
# The property: description, has value nan, in item with pid: tools/yj8QLL, (current version: 49729)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/I6hy1i, (current version: 49730)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/XZT3Pl, (current version: 49731)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Lvr9L8, (current version: 62581)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/5qBxUJ, (current version: 49733)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/yRXtvk, (current version: 49734)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/djTrLN, (current version: 61495)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}], 'description':  {"length": "0"}}
# The property: description, has value 1547.0, in item with pid: tools/Tr5GZ4, (current version: 49736)
# flag property exists, value:  {'description':  {"length": "1547"}}
# The property: description, has value 16.0, in item with pid: tools/7gTHnZ, (current version: 49737)
# flag property exists, value:  {'description':  {"length": "16"}}
# The property: description, has value nan, in item with pid: tools/icC9NA, (current version: 49738)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/tiupRp, (current version: 49739)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/M204gA, (current version: 49740)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/LGEEtV, (current version: 49741)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ExAEch, (current version: 49742)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/5uwI5b, (current version: 49743)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/ibVtGt, (current version: 49744)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/yZJ6ox, (current version: 49745)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/0RoWpO, (current version: 49746)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/eNjUS0, (current version: 49747)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/gLeAJL, (current version: 49749)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/P55rnx, (current version: 49748)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 4.0, in item with pid: tools/NF1hKw, (current version: 49754)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/TdQvqM, (current version: 49753)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/MUiL42, (current version: 49752)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 4.0, in item with pid: tools/3lO2BY, (current version: 49750)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 15.0, in item with pid: tools/x1opwS, (current version: 63914)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "15.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 18.0, in item with pid: tools/wOID3C, (current version: 49755)
# flag property exists, value:  {'description':  {"length": "18"}}
# The property: description, has value 19.0, in item with pid: tools/CHvh15, (current version: 50003)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "19.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 21.0, in item with pid: tools/mBKLD8, (current version: 63916)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "21.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 23.0, in item with pid: tools/lE3Tzd, (current version: 63662)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "23.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 15.0, in item with pid: tools/uPWIlr, (current version: 63918)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "15.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 20.0, in item with pid: tools/IwGbG0, (current version: 63920)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "20.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4.0, in item with pid: tools/6xxzE2, (current version: 49756)
# flag property exists, value:  {'description':  {"length": "4"}}
# The property: description, has value 16.0, in item with pid: tools/39rJ20, (current version: 49760)
# flag property exists, value:  {'description':  {"length": "16"}}
# The property: description, has value 16.0, in item with pid: tools/kzORM2, (current version: 49759)
# flag property exists, value:  {'description':  {"length": "16"}}
# The property: description, has value 16.0, in item with pid: tools/IVCM1Q, (current version: 49758)
# flag property exists, value:  {'description':  {"length": "16"}}
# The property: description, has value 16.0, in item with pid: tools/nUQK4V, (current version: 49757)
# flag property exists, value:  {'description':  {"length": "16"}}
# The property: description, has value 23.0, in item with pid: tools/DHcf5z, (current version: 63911)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "23.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1572.0, in item with pid: tools/D3VUbY, (current version: 49761)
# flag property exists, value:  {'description':  {"length": "1572"}}
# The property: description, has value 2033.0, in item with pid: tools/mQtVsG, (current version: 49762)
# flag property exists, value:  {'description':  {"length": "2033"}}
# The property: description, has value nan, in item with pid: tools/dbGwJK, (current version: 49763)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/bjV8Vi, (current version: 49764)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/jNo1zf, (current version: 49765)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1.0, in item with pid: tools/SgJ8Uy, (current version: 64052)
# append curation_property_value
# append curation_detail_value {'type': {'code': 'curation-detail'}, 'value': '{"description": {"length": "1.0"}}'}
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: tools/HuczGF, (current version: 49766)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/Lv8r1R, (current version: 49767)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/wq6SYr, (current version: 49768)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/a3jBMm, (current version: 49769)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/zIjiku, (current version: 49771)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/1Nh8B4, (current version: 49770)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 2985.0, in item with pid: tools/A5qt7q, (current version: 49772)
# flag property exists, value:  {'description':  {"length": "2985"}}
# The property: description, has value nan, in item with pid: tools/fnRO5e, (current version: 49773)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/HQjxLh, (current version: 49774)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/tBrNgv, (current version: 63022)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/iv2I5L, (current version: 49776)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/DFupiA, (current version: 61493)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/iSBDle, (current version: 49778)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/sfdcvb, (current version: 49779)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/RAIGIx, (current version: 49780)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/7iLFx1, (current version: 49781)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/X18GYl, (current version: 49782)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/xPPgAY, (current version: 49783)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/SFWYbc, (current version: 49784)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/6YC72t, (current version: 49785)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/p1Tfe7, (current version: 49786)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/BnctnS, (current version: 49787)
# flag property exists, value:  {'url': [ {"accessibleAt": "404"}], 'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/hw6a4s, (current version: 49788)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value nan, in item with pid: tools/4Olcmh, (current version: 49789)
# flag property exists, value:  {'description':  {"length": "0"}}
# The property: description, has value 1702.0, in item with pid: tools/Qeqmj9, (current version: 49790)
# flag property exists, value:  {'description':  {"length": "1702"}}
# The property: description, has value nan, in item with pid: tools/M3AICu, (current version: 49791)
# flag property exists, value:  {'description':  {"length": "0"}}
