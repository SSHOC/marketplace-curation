# %% [markdown]
# # Notebook 3.2 - Curation-flag-description
#
# This notebook analyses the `description` fields of the SSH Open Marketplace and writes back to the system via two dedicated curation properties: `curation-flag-description` and `curation-detail` properties.
#
# This notebook flags Marketplace items that have empty, too short or too long descriptions, helping Moderators identify curation priorities to improve data quality.
#
# This notebook is part of a series of 4 notebooks that inform the curation properties used in the SSH Open Marketplace Editorial Dashboard.
#
# It is composed of 3 sections:
#
# 0. Requirements to run the notebook
# 1. Check the length of the text stored in the `description` field
# 2. Flag items with empty/short/long `description` in the Dataset

# %% [markdown]
# ## 0 Requirements to run this notebook
#
# This section gives all the relevant information to "interact" with the MP data.
#
# ### 0.1 libraries
# *There are a number of external libraries needed to run the notebook*
#
# *Furthermore, a dedicated SSH Open Marketplace library - sshmarketplacelib - with customised functions has been created and can be imported using the python import commands.*
#
# *Below the libraries import needed to run this notebook*

# %%
import numpy as np
import pandas as pd
import requests
#import the MarketPlace Library 
from sshmarketplacelib import MPData as mpd
from sshmarketplacelib import  eval as eva, helper as hel

# %% [markdown]
# ### 0.2 Get the data

# %%
mpdata = mpd()
df_tool_flat =mpdata.getMPItems ("toolsandservices", True)
df_publication_flat =mpdata.getMPItems ("publications", True)
df_trainingmaterials_flat =mpdata.getMPItems ("trainingmaterials", True)
df_workflows_flat =mpdata.getMPItems ("workflows", True)
df_datasets_flat =mpdata.getMPItems ("datasets", True)
# Out:
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...
# getting data from local repository...

# %% [markdown]
# ### 0.3 A look at the data

# %%
df_all_items=pd.concat([df_tool_flat, df_publication_flat, df_trainingmaterials_flat, df_workflows_flat, df_datasets_flat])
df_all_items.head()
# Out:
#       id         category                                              label  \
# 0  28230  tool-or-service                                             140kit
# 1  36324  tool-or-service  3DF Zephyr - photogrammetry software - 3d mode...
# 2  36552  tool-or-service                                              3DHOP
# 3  36555  tool-or-service                3DHOP: 3D Heritage Online Presenter
# 4  36189  tool-or-service                           3DReshaper \| 3DReshaper
#
#   persistentId            lastInfoUpdate    status  \
# 0       SIU1nO  2021-11-23T17:24:25+0000  approved
# 1       4gDAHv  2022-01-13T11:49:02+0000  approved
# 2       UcxOmD  2022-01-13T11:50:31+0000  approved
# 3       uFIMPQ  2022-01-13T11:50:32+0000  approved
# 4       kAkzuz  2022-01-13T11:47:44+0000  approved
#
#                                          description  \
# 0  140kit provides a management layer for tweet c...
# 1  3DF Zephyr\[1\]\[2\] is a commercial photogram...
# 2  3DHOP (3D Heritage Online Presenter) is an ope...
# 3                           No description provided.
# 4                           No description provided.
#
#                                         contributors  \
# 0  [{'actor': {'id': 2224, 'name': 'Ian Pearce, D...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                           properties externalIds  ...  \
# 0  [{'type': {'code': 'mode-of-use', 'label': 'Mo...          []  ...
# 1  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 2  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
# 3                                                 []          []  ...
# 4  [{'type': {'code': 'language', 'label': 'Langu...          []  ...
#
#   thumbnail.info.mediaId thumbnail.info.category thumbnail.info.filename  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#   thumbnail.info.mimeType  thumbnail.info.hasThumbnail  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#   thumbnail.info.location.sourceUrl thumbnail.caption dateCreated  \
# 0                               NaN               NaN         NaN
# 1                               NaN               NaN         NaN
# 2                               NaN               NaN         NaN
# 3                               NaN               NaN         NaN
# 4                               NaN               NaN         NaN
#
#   dateLastUpdated composedOf
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
#
# [5 rows x 37 columns]

# %%
df_all_items_work=df_all_items[['id', 'persistentId', 'category', 'label', 'description', 'contributors', 'accessibleAt', 'source.label']]
df_all_items_work.tail()
# Out:
#         id persistentId category  \
# 303  12634       l8gLBb  dataset
# 304  12631       xvYQQ4  dataset
# 305  12632       IdZGtV  dataset
# 306  12633       OMny6U  dataset
# 307  12589       YnEaU0  dataset
#
#                                                  label  \
# 303                    Yelp Academic Challenge Dataset
# 304                                            YelpCHI
# 305                                            YelpNYC
# 306                                            YelpZIP
# 307  "You Are Where You Tweet: A Content-Based Appr...
#
#                                            description  \
# 303  The Yelp dataset is a subset of our businesses...
# 304  This dataset is collected from Yelp.com and fi...
# 305  This dataset is collected from Yelp.com and fi...
# 306  This dataset is collected from Yelp.com and fi...
# 307  This dataset is a collection of scraped public...
#
#                                           contributors  \
# 303  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 304  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 305  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 306  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
# 307  [{'actor': {'id': 1752, 'name': 'Eva Bacas', '...
#
#                                          accessibleAt     source.label
# 303                    [https://www.yelp.com/dataset]  Humanities Data
# 304  [http://odds.cs.stonybrook.edu/yelpchi-dataset/]  Humanities Data
# 305  [http://odds.cs.stonybrook.edu/yelpnyc-dataset/]  Humanities Data
# 306  [http://odds.cs.stonybrook.edu/yelpzip-dataset/]  Humanities Data
# 307   [https://archive.org/details/twitter_cikm_2010]  Humanities Data

# %% [markdown]
# ## 1. Check the length of the text stored in the `description` field
#
# By default, and according to rules set up in the Editorial Guidelines [add link], the minimum number of characters is set up to 25 and the maximum to 1500, but these parameters can be modified in the cell below.
#
# An overview of the items description length is also given in notebook *2.SSH Open Marketplace data quality overview*

# %%
minchars=25
maxchars=1500

utils=hel.Util()

df_items = df_tool_flat.replace(utils.empty_description, np.nan)

df_items_d = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()>=minchars) & (df_items['description'].str.len()<=maxchars)]

df_items_min = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()<minchars)]

df_items_max = df_items[(df_items['description'].notnull()) & (df_items['description'].str.len()>maxchars)]

print (f"\nThere are {df_items['description'].isna().sum()} items with empty descriptions, "+
       f" {df_items_min['description'].count()} items with description shorter than {minchars} characters,"+
f" {df_items_max['description'].count()} Items with description longer than {maxchars} characters, "+
      f" {df_items_d['description'].count()} Items with description between {minchars} and {maxchars} characters.")
# Out:
# There are 55 items with empty descriptions,  2 items with description shorter than 25 characters, 29 Items with description longer than 1500 characters,  1609 Items with description between 25 and 1500 characters.

# %%
df_items_null = df_items[(df_items['description'].isnull())]

# %%
nv_description_df=pd.concat([df_items_min, df_items_max, df_items_null])
tempdf=nv_description_df[['persistentId', 'label', 'description']]
tempdf['property']='description'
tempdf['value']=tempdf['description'].str.len()
# Out:
# <ipython-input-7-969ed00ad054>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['property']='description'
# <ipython-input-7-969ed00ad054>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['value']=tempdf['description'].str.len()

# %%
tempdf.to_pickle('data/descrlength.pickle')

# %%
tempdf.head()
# Out:
#     persistentId                                     label  \
# 194       o2X2Sl                                   Chartle
# 917       5jMQ6a  Offline Getting Started and Manual (pdf)
# 84        S9m9UW                             Artifex Press
# 87        EdUOYX                                Asset Bank
# 114       WnrT3t                     Bamboo Person Service
#
#                                            description     property   value
# 194                            Create simple charts.\n  description    22.0
# 917                            Last Update: 14.12.2017  description    23.0
# 84   Artifex Press is a publishing and technology c...  description  3256.0
# 87   A digital asset management system for the stor...  description  1839.0
# 114  The Bamboo Person Service can help scholars ac...  description  1710.0

# %% [markdown]
# ## 2. Flag items with empty/short/long `description` in the Dataset

# %%
curation_flag_property={"code": "curation-flag-description"}
curation_detail_property={"code": "curation-detail"}

# %%
# categories="toolsandservices";"publications";"trainingmaterials";"workflows";"datasets"
# res=mpdata.setPropertyStatusFlags(tempdf, categories, curation_flag_property, curation_detail_property)
res_des=mpdata.setPropertyFlags(tempdf, curation_flag_property, curation_detail_property)
# Out:
# Creating log file...
# The property: description, has value nan, in item with pid: uFIMPQ, (current version: 36555)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: kAkzuz, (current version: 36189)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 3256.0, in item with pid: S9m9UW, (current version: 27957)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1839.0, in item with pid: EdUOYX, (current version: 27701)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: bhZPRG, (current version: 35694)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1710.0, in item with pid: WnrT3t, (current version: 27702)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: f2Lqiq, (current version: 36900)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: SkWj85, (current version: 36906)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: yks1mq, (current version: 36534)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 22.0, in item with pid: o2X2Sl, (current version: 34605)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1806.0, in item with pid: XYWXCZ, (current version: 28793)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: butGX1, (current version: 36903)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1815.0, in item with pid: cZJbuk, (current version: 28352)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 3757.0, in item with pid: JZuVsb, (current version: 40028)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: A9nRNi, (current version: 35709)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1796.0, in item with pid: f6Tch2, (current version: 40011)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: hnwnQN, (current version: 36561)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 9snWhS, (current version: 36567)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: MkXY6u, (current version: 7256)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: NQ76Ma, (current version: 7379)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2633.0, in item with pid: vnUaYG, (current version: 29313)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1664.0, in item with pid: 8g3Yzt, (current version: 35622)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2294.0, in item with pid: K4xToD, (current version: 40014)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 02gzWL, (current version: 36834)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2855.0, in item with pid: OKoqgh, (current version: 29149)
# Appending curation_detail_flag  {'url': [ {'description': '2855.0'},  {"accessibleAt": "404"}]}
# append curation_property_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: OB34AB, (current version: 35715)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: rlSTxc, (current version: 28189)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1829.0, in item with pid: raCHUH, (current version: 28731)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1663.0, in item with pid: rQYLSw, (current version: 27713)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: Y6Cix8, (current version: 28903)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 6vEKc5, (current version: 36306)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: tjXYZn, (current version: 36597)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 1KBLSJ, (current version: 35724)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2673.0, in item with pid: xQMWDs, (current version: 28338)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: zUk8Vg, (current version: 36657)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: BqRa2R, (current version: 36510)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2973.0, in item with pid: u3Ync0, (current version: 34635)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 4QzgD9, (current version: 35721)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: aY4ryv, (current version: 36006)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2347.0, in item with pid: OJcHh4, (current version: 40455)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: nwihVQ, (current version: 35871)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 7ckBdR, (current version: 35727)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 4n69Z0, (current version: 36123)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: sXaPdJ, (current version: 36990)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: Ew8dCW, (current version: 9631)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 2B2808, (current version: 36180)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: jW7Juy, (current version: 36711)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: GjUxgN, (current version: 36828)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: SdCJsn, (current version: 28638)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: eysS8u, (current version: 36036)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: ifbGOh, (current version: 36807)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: nRLBSG, (current version: 35742)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: iO9k1Y, (current version: 35691)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 23.0, in item with pid: 5jMQ6a, (current version: 36492)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: veS7n4, (current version: 36603)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1705.0, in item with pid: MHE8cr, (current version: 28678)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 3OLou6, (current version: 36345)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 3980.0, in item with pid: IClmD1, (current version: 35458)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1778.0, in item with pid: E9dIJj, (current version: 27704)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: fxiQ6O, (current version: 36651)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1602.0, in item with pid: 2tO2SM, (current version: 40022)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: PhTbBl, (current version: 36543)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1548.0, in item with pid: sSy5hU, (current version: 40424)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: vTakO9, (current version: 29077)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: uCs1QG, (current version: 36654)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 1RvNt3, (current version: 36780)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4003.0, in item with pid: bs2yJD, (current version: 40027)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1547.0, in item with pid: 34pYcH, (current version: 29125)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: 2CJSrL, (current version: 36486)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: Zot7pm, (current version: 36879)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: zh8f0u, (current version: 35889)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: fs8Li3, (current version: 36876)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1572.0, in item with pid: 71BVDP, (current version: 28772)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2033.0, in item with pid: JWKTKK, (current version: 28664)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: mZ8s4O, (current version: 36996)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 4063.0, in item with pid: br2KgP, (current version: 37003)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: mwagdK, (current version: 36963)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 2985.0, in item with pid: CInBcH, (current version: 28117)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: FVMjiZ, (current version: 36270)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: HLlsDS, (current version: 36825)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: MmB0aX, (current version: 36573)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: xAW2Dh, (current version: 36600)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: Vckyp6, (current version: 35718)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value nan, in item with pid: rFuWdh, (current version: 36519)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1790.0, in item with pid: jOJO6j, (current version: 40430)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
# The property: description, has value 1699.0, in item with pid: 2qgaRK, (current version: 34702)
# append curation_property_value
# append curation_detail_value
#
# Running in debug mode, Marketplace dataset not updated.
